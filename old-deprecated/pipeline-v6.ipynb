# %%
import feedparser
from openai import OpenAI
import datetime
from dateutil import parser as dateparser
import json
import requests
import os
from bs4 import BeautifulSoup # For cleaning HTML from summaries
from dotenv import load_dotenv

# ------------- CONFIG ----------------

# Load environment variables from .env file (must be in the same directory)
load_dotenv()
   
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
  
if not OPENAI_API_KEY:
	raise ValueError("OPENAI_API_KEY not found. Make sure it's set in your .env file.")

# Use the modern OpenAI client
client = OpenAI(api_key=OPENAI_API_KEY)

# Using gpt-4o-mini: faster, more capable, and cost-effective for this task.
LLM_MODEL = "gpt-4o-mini"

# --- User-Curated RSS Feeds ---
RSS_FEEDS = {
    # NEP - Economics
    "NEP-FOR": "https://nep.repec.org/rss/nep-for.rss.xml",   # **Forecasting** (Most Important)
    "NEP-ETS": "https://nep.repec.org/rss/nep-ets.rss.xml",   # Econometric Time Series
    "NEP-BIG": "https://nep.repec.org/rss/nep-big.rss.xml",   # Big Data
    "NEP-CMP": "https://nep.repec.org/rss/nep-cmp.rss.xml",   # Computational Economics
    "NEP-MAC": "https://nep.repec.org/rss/nep-mac.rss.xml",   # Macroeconomics
    "NEP-MON": "https://nep.repec.org/rss/nep-mon.rss.xml",   # Monetary Economics
    "NEP-MFD": "https://nep.repec.org/rss/nep-mfd.rss.xml",   # Macrofinance
    "NEP-CBA": "https://nep.repec.org/rss/nep-cba.rss.xml",   # Central Banking
    "NEP-AIN": "https://nep.repec.org/rss/nep-ain.rss.xml",   # Artificial Intelligence
    "NEP-IFN": "https://nep.repec.org/rss/nep-ifn.rss.xml",   # International Finance
    
    # NEP - Finance
    "NEP-FMK": "https://nep.repec.org/rss/nep-fmk.rss.xml",   # Financial Markets
    "NEP-RMG": "https://nep.repec.org/rss/nep-rmg.rss.xml",   # Risk Management
    "NEP-PPM": "https://nep.repec.org/rss/nep-ppm.rss.xml",   # Project, Program and Portfolio Management

    # NEP - Energy & Resource Focused
    "NEP-ENE": "https://nep.repec.org/rss/nep-ene.rss.xml",   # Energy Economics
    "NEP-RES": "https://nep.repec.org/rss/nep-res.rss.xml",   # Resource Economics

    # ArXiv - Core Quantitative & CS Fields
    "arXiv-econEM": "http://export.arxiv.org/rss/econ.EM",     # Econometrics
    "arXiv-statML": "http://export.arxiv.org/rss/stat.ML",     # Statistics - Machine Learning
    "arXiv-csLG": "http://export.arxiv.org/rss/cs.LG",         # Computer Science - Machine Learning
    "arXiv-qFIN-ST": "http://export.arxiv.org/rss/q-fin.ST",   # Quantitative Finance - Statistical Methods
    "arXiv-qFIN-CP": "http://export.arxiv.org/rss/q-fin.CP",   # Quantitative Finance - Computational Finance

    # High-Signal Institutions (Central Banks & Academic Orgs)
    "FEDS_Papers": "https://www.federalreserve.gov/feeds/working_papers.xml",     # US Federal Reserve Board
    "ECB_Papers": "https://www.ecb.europa.eu/rss/pub.html",                       # European Central Bank
    "IMF_Papers": "https://www.imf.org/en/Publications/RSS?language=eng&series=IMF%20Working%20Papers", # International Monetary Fund
    "BIS_Papers": "https://www.bis.org/doclist/bis_fsi_publs.rss",                # Bank for International Settlements
    "CEPR_Papers": "https://cepr.org/rss/discussion-paper",                       # Centre for Economic Policy Research (CEPR)
}


SCORE_THRESHOLD = 7.0  # Keep only papers scoring above this
DAYS_BACK = 35         # Look back this many days
OUTPUT_DIR = "newsletters"

# ------------- HELPER FUNCTIONS ----------------

def _get_authors(entry):
    """Normalizes author information from a feed entry."""
    if hasattr(entry, 'authors') and entry.authors:
        return ', '.join(author['name'] for author in entry.authors if 'name' in author)
    if hasattr(entry, 'author'):
        return entry.author
    return "Unknown"

# ------------- CORE FUNCTIONS ----------------

def fetch_recent_papers():
    """Fetch recent papers from RSS feeds with robust date parsing and encoding correction."""
    print(f"Fetching papers from {len(RSS_FEEDS)} sources, looking back {DAYS_BACK} days...")
    cutoff_date = datetime.datetime.now(datetime.timezone.utc) - datetime.timedelta(days=DAYS_BACK)
    papers = []

    for source, url in RSS_FEEDS.items():
        print(f"  - Processing {source} from {url}")
        try:
            response = requests.get(url, timeout=15)
            if "utf-8" in response.text.lower() or "<?xml" in response.text:
                response.encoding = "utf-8"
            feed = feedparser.parse(response.text)
            if feed.bozo:
                print(f"    Warning: Malformed feed for {source}. Error: {feed.bozo_exception}")

            found_in_feed = 0
            for entry in feed.entries:
                pub_date_str = getattr(entry, "published", getattr(entry, "updated", None))
                if not pub_date_str: continue
                try:
                    pub_date = dateparser.parse(pub_date_str)
                except dateparser.ParserError:
                    continue
                if pub_date.tzinfo is None:
                    pub_date = pub_date.replace(tzinfo=datetime.timezone.utc)
                if pub_date < cutoff_date: continue
                summary = getattr(entry, "summary", "")
                if "<" in summary and ">" in summary:
                    summary = BeautifulSoup(summary, "html.parser").get_text(separator=' ', strip=True)
                papers.append({
                    "title": entry.title, "link": entry.link, "summary": summary,
                    "authors": _get_authors(entry), "source": source, "date": pub_date.strftime("%Y-%m-%d")
                })
                found_in_feed += 1
            print(f"    Found {found_in_feed} recent papers in {source}.")
        except Exception as e:
            print(f"    Error fetching or parsing feed {source}: {e}")
            continue
    return papers

def score_and_summarize(paper):
    """Sends abstract to LLM for summary, scoring, and categorization."""
    prompt = f"""
You are a highly specialized expert curator for "ets4 Monthly (Economic Time Series Forecasting Monthly)," a newsletter focused **exclusively on practical and impactful forecasting of economic time series.** Your role is to identify only the most relevant and innovative work for an audience of researchers and practitioners.

You will be given a research paper. Evaluate it strictly through the lens of **forecasting relevance and potential to advance economic prediction.** Papers that focus on **structural analysis, causal inference, descriptive statistics, or purely theoretical econometrics without a predictive component must be classified as Not Relevant**, even if they appear in economics journals.

---

**Paper Information**

Title: {paper['title']}
Authors: {paper['authors']}
Source: {paper['source']}
Date: {paper['date']}
Abstract: {paper['summary']}

---

### Your Tasks

1. **Summarize (3-4 sentences)**  
   Focus only on elements related to **forecasting or predictive modeling**. If forecasting is not clearly present, explicitly say so.

2. **Assign a Quality Score (1–10)**  
   Score based on **forecasting methodological novelty, empirical rigor, and potential practical impact.**  
   - **Extra weight should be given** to papers that:
     - Introduce **new modeling approaches** or **improve existing ones significantly**.
     - Use **novel datasets** that could meaningfully enhance economic forecasting.
     - Present **forecasting applications with real-world decision value** (e.g. monetary policy, energy prices, financial trading, inflation nowcasting).

3. **Classify into One Category**  
   Choose exactly one:
   - **Directly Relevant** → The paper is clearly about **forecasting *economic* time series** and offers meaningful contributions or applications.
   - **Paper of Interest** → The paper is *not economic*, but presents **highly innovative forecasting methods or data strategies** that could plausibly transfer to economics.
   - **Not Relevant** → No clear predictive component, or relevance is too indirect (e.g., **structural models, policy simulations without forecasting, causal effects estimation, variance decompositions, statistical/econometric theory without prediction focus**).

---

### Scoring & Categorization Rules

| Score | Meaning | Default Category |
|--------|---------|------------------|
| **1–3** | Low quality OR no forecasting at all | Not Relevant |
| **4–6** | Minor/incremental forecasting contribution OR niche application with little general value | Not Relevant |
| **7–8** | Solid contribution to forecasting | Directly Relevant *if economic*, otherwise Paper of Interest |
| **9–10** | Breakthrough forecasting methodology, dataset, or application with clear future impact | Directly Relevant *if economic*, otherwise Paper of Interest |

---

### JSON Output Format

Return your response strictly in **valid JSON** using the following schema:

{{
"summary": "...",
"score": X,
"category": "Directly Relevant" | "Paper of Interest" | "Not Relevant",
"adaptability_reason": null | "Required only if category is 'Paper of Interest'"
}}

- If you select **Paper of Interest**, you **must** fill in `"adaptability_reason"` with a short statement explaining how the method could be applied to economic forecasting.
- For **Directly Relevant** or **Not Relevant**, set `"adaptability_reason": null`.
"""
    try:
        response = client.chat.completions.create(
            model=LLM_MODEL,
            messages=[{"role": "user", "content": prompt}],
            temperature=0.2,
            response_format={"type": "json_object"}
        )
        content = response.choices[0].message.content
        data = json.loads(content)
        required_keys = ["summary", "score", "category", "adaptability_reason"]
        if not all(key in data for key in required_keys):
            raise ValueError(f"LLM response missing one or more required keys: {required_keys}")
        if not isinstance(data["score"], (int, float)):
            raise ValueError("LLM score is not a number.")
        if data["category"] == "Paper of Interest" and not data.get("adaptability_reason"):
            raise ValueError("Category is 'Paper of Interest' but adaptability_reason is missing.")
        data["score"] = float(data["score"])
        return data
    except Exception as e:
        print(f"Error during LLM call for paper '{paper['title']}': {e}")
        return {"summary": f"Error: {e}", "score": 0.0, "category": "Not Relevant", "adaptability_reason": None}

def build_internal_markdown(relevant_papers, interest_papers, filename):
    """Creates the internal markdown file WITH scores for review."""
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    today_str = datetime.date.today().strftime('%Y-%m-%d')
    lines = [f"# ets4 Monthly [INTERNAL] – {today_str}\n", "Internal review copy with quality scores.\n"]
    lines.append("## Directly Relevant Papers\n")
    if not relevant_papers:
        lines.append("No directly relevant papers met the criteria this week.\n")
    else:
        relevant_papers.sort(key=lambda p: p['score'], reverse=True)
        for p in relevant_papers:
            lines.append(f"### [{p['title']}]({p['link']})")
            lines.append(f"- **Authors:** {p['authors']}")
            lines.append(f"- **Source:** {p['source']} ({p['date']})")
            lines.append(f"- **Quality Score:** {p['score']:.1f}/10") # SCORE IS INCLUDED
            lines.append(f"- **Summary:** {p['summary']}\n")
    lines.append("\n---\n")
    lines.append("## Papers of Interest\n")
    if not interest_papers:
        lines.append("No papers of interest were identified this week.\n")
    else:
        interest_papers.sort(key=lambda p: p['score'], reverse=True)
        for p in interest_papers:
            lines.append(f"### [{p['title']}]({p['link']})")
            lines.append(f"- **Authors:** {p['authors']}")
            lines.append(f"- **Source:** {p['source']} ({p['date']})")
            lines.append(f"- **Quality Score:** {p['score']:.1f}/10") # SCORE IS INCLUDED
            lines.append(f"- **Summary:** {p['summary']}")
            lines.append(f"- **Reason for Interest:** {p.get('adaptability_reason', 'N/A')}\n")
    with open(filename, "w", encoding="utf-8") as f:
        f.write("\n".join(lines))
    print(f"✅ Internal review file saved: {filename}")

def build_public_markdown(relevant_papers, interest_papers, filename):
    """Creates the public-facing markdown file WITHOUT scores and WITH Hugo front matter."""
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    today = datetime.date.today()
    
    # --- Create date strings in the required formats ---
    iso_date_str = today.strftime('%Y-%m-%d')
    title_date_str = today.strftime('%B %d, %Y') # e.g., October 27, 2023

    # --- Construct the Hugo front matter block ---
    front_matter = f"""---
title: "ets4 Newsletter, {title_date_str}"
date: {iso_date_str}
draft: true
---
"""

    # --- Start the file with the front matter ---
    lines = [
        front_matter,
        f"# ets4 Monthly – {iso_date_str}\n",
        "A curated list of recent papers on novel methods for forecasting economic time series.\n"
    ]

    lines.append("## Directly Relevant Papers\n")
    if not relevant_papers:
        lines.append("No directly relevant papers met the criteria this week.\n")
    else:
        relevant_papers.sort(key=lambda p: p['score'], reverse=True)
        for p in relevant_papers:
            lines.append(f"### [{p['title']}]({p['link']})")
            lines.append(f"- **Authors:** {p['authors']}")
            lines.append(f"- **Source:** {p['source']} ({p['date']})")
            lines.append(f"- **Summary:** {p['summary']}\n")
    
    lines.append("\n---\n")
    lines.append("## Papers of Interest\n")
    lines.append("_Methodologically novel papers from other fields that could be adapted for economic forecasting._\n")
    if not interest_papers:
        lines.append("No papers of interest were identified this week.\n")
    else:
        interest_papers.sort(key=lambda p: p['score'], reverse=True)
        for p in interest_papers:
            lines.append(f"### [{p['title']}]({p['link']})")
            lines.append(f"- **Authors:** {p['authors']}")
            lines.append(f"- **Source:** {p['source']} ({p['date']})")
            lines.append(f"- **Summary:** {p['summary']}")
            lines.append(f"- **Reason for Interest:** {p.get('adaptability_reason', 'N/A')}\n")

    with open(filename, "w", encoding="utf-8") as f:
        f.write("\n".join(lines))
    print(f"✅ Public newsletter file saved: {filename}")

# ------------- MAIN ----------------

if __name__ == "__main__":
    print("Starting Economic Forecasting Newsletter Pipeline...")
    all_papers = fetch_recent_papers()
    print(f"Found {len(all_papers)} total recent papers.")
    unique_papers = []
    seen_links = set()
    for paper in all_papers:
        if paper['link'] not in seen_links:
            unique_papers.append(paper)
            seen_links.add(paper['link'])
    if len(all_papers) > len(unique_papers):
        print(f"Removed {len(all_papers) - len(unique_papers)} duplicates. Processing {len(unique_papers)} unique papers.")
    shortlisted_relevant = []
    shortlisted_interest = []
    for i, paper in enumerate(unique_papers, 1):
        print(f"Processing paper {i}/{len(unique_papers)}: '{paper['title'][:70]}...'")
        result = score_and_summarize(paper)
        paper.update(result)
        if paper.get("score", 0.0) >= SCORE_THRESHOLD:
            if paper.get("category") == "Directly Relevant":
                shortlisted_relevant.append(paper)
                print(f"  -> Shortlisted! (Relevant) Score: {paper['score']:.1f}/10")
            elif paper.get("category") == "Paper of Interest":
                shortlisted_interest.append(paper)
                print(f"  -> Shortlisted! (Interest) Score: {paper['score']:.1f}/10")
            else:
                print(f"  -> Skipped. Category: {paper.get('category', 'Unknown')}, Score: {paper['score']:.1f}/10")
        else:
            print(f"  -> Skipped. Score below threshold: {paper.get('score', 0.0):.1f}/10")
    
    today_str = datetime.date.today().strftime("%Y-%m-%d")
    internal_filename = os.path.join(OUTPUT_DIR, f"ets4_monthly_{today_str}_INTERNAL.md")
    public_filename = os.path.join(OUTPUT_DIR, f"ets4_monthly_{today_str}_PUBLIC.md")
    
    build_internal_markdown(shortlisted_relevant, shortlisted_interest, internal_filename)
    build_public_markdown(shortlisted_relevant, shortlisted_interest, public_filename)
    
    print("\n--- Pipeline Finished ---")
    print(f"Total unique papers processed by LLM: {len(unique_papers)}")
    print(f"Shortlisted {len(shortlisted_relevant)} 'Directly Relevant' papers.")
    print(f"Shortlisted {len(shortlisted_interest)} 'Papers of Interest'.")
# Out:
# Starting Economic Forecasting Newsletter Pipeline...
# Fetching papers from 25 sources, looking back 35 days...
#   - Processing NEP-FOR from https://nep.repec.org/rss/nep-for.rss.xml
#     Found 17 recent papers in NEP-FOR.
#   - Processing NEP-ETS from https://nep.repec.org/rss/nep-ets.rss.xml
#     Found 3 recent papers in NEP-ETS.
#   - Processing NEP-BIG from https://nep.repec.org/rss/nep-big.rss.xml
#     Found 17 recent papers in NEP-BIG.
#   - Processing NEP-CMP from https://nep.repec.org/rss/nep-cmp.rss.xml
#     Found 18 recent papers in NEP-CMP.
#   - Processing NEP-MAC from https://nep.repec.org/rss/nep-mac.rss.xml
#     Found 14 recent papers in NEP-MAC.
#   - Processing NEP-MON from https://nep.repec.org/rss/nep-mon.rss.xml
#     Found 26 recent papers in NEP-MON.
#   - Processing NEP-MFD from https://nep.repec.org/rss/nep-mfd.rss.xml
#     Found 1 recent papers in NEP-MFD.
#   - Processing NEP-CBA from https://nep.repec.org/rss/nep-cba.rss.xml
#     Found 14 recent papers in NEP-CBA.
#   - Processing NEP-AIN from https://nep.repec.org/rss/nep-ain.rss.xml
#     Found 5 recent papers in NEP-AIN.
#   - Processing NEP-IFN from https://nep.repec.org/rss/nep-ifn.rss.xml
#     Found 12 recent papers in NEP-IFN.
#   - Processing NEP-FMK from https://nep.repec.org/rss/nep-fmk.rss.xml
#     Found 4 recent papers in NEP-FMK.
#   - Processing NEP-RMG from https://nep.repec.org/rss/nep-rmg.rss.xml
#     Found 18 recent papers in NEP-RMG.
#   - Processing NEP-PPM from https://nep.repec.org/rss/nep-ppm.rss.xml
#     Found 4 recent papers in NEP-PPM.
#   - Processing NEP-ENE from https://nep.repec.org/rss/nep-ene.rss.xml
#     Found 26 recent papers in NEP-ENE.
#   - Processing NEP-RES from https://nep.repec.org/rss/nep-res.rss.xml
#     Found 3 recent papers in NEP-RES.
#   - Processing arXiv-econEM from http://export.arxiv.org/rss/econ.EM
#     Found 0 recent papers in arXiv-econEM.
#   - Processing arXiv-statML from http://export.arxiv.org/rss/stat.ML
#     Found 0 recent papers in arXiv-statML.
#   - Processing arXiv-csLG from http://export.arxiv.org/rss/cs.LG
#     Found 0 recent papers in arXiv-csLG.
#   - Processing arXiv-qFIN-ST from http://export.arxiv.org/rss/q-fin.ST
#     Found 0 recent papers in arXiv-qFIN-ST.
#   - Processing arXiv-qFIN-CP from http://export.arxiv.org/rss/q-fin.CP
#     Found 0 recent papers in arXiv-qFIN-CP.
#   - Processing FEDS_Papers from https://www.federalreserve.gov/feeds/working_papers.xml
#     Found 15 recent papers in FEDS_Papers.
#   - Processing ECB_Papers from https://www.ecb.europa.eu/rss/pub.html
#     Found 15 recent papers in ECB_Papers.
#   - Processing IMF_Papers from https://www.imf.org/en/Publications/RSS?language=eng&series=IMF%20Working%20Papers
#     Found 10 recent papers in IMF_Papers.
#   - Processing BIS_Papers from https://www.bis.org/doclist/bis_fsi_publs.rss
#     Found 3 recent papers in BIS_Papers.
#   - Processing CEPR_Papers from https://cepr.org/rss/discussion-paper
#     Found 50 recent papers in CEPR_Papers.
# Found 275 total recent papers.
# Processing paper 1/275: 'Neural ARFIMA model for forecasting BRIC exchange rates with long memo...'
#   -> Shortlisted! (Relevant) Score: 9.0/10
# Processing paper 2/275: 'Finance-Grounded Optimization For Algorithmic Trading...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 3/275: 'Volatility Modeling via EWMA-Driven Time-Dependent Hurst Parameters...'
#   -> Shortlisted! (Interest) Score: 8.0/10
# Processing paper 4/275: 'Expectations, Learning Gains, and Forecast Errors: Assessing Nonlinear...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 5/275: 'A Bayesian Gaussian Process Dynamic Factor Model...'
#   -> Shortlisted! (Relevant) Score: 9.0/10
# Processing paper 6/275: 'An Interpretable Deep Learning Model for General Insurance Pricing...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 7/275: 'An Economic Framework to Nowcast Low-Frequency Data...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 8/275: 'Beyond GARCH: Bayesian Neural Stochastic Volatility...'
#   -> Shortlisted! (Relevant) Score: 9.0/10
# Processing paper 9/275: 'Out-of-Sample Inference with Annual Benchmark Revisions...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 10/275: 'Deep Learning Option Pricing with Market Implied Volatility Surfaces...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 11/275: 'Random Forests for Labor Market Analysis: Balancing Precision and Inte...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 12/275: 'Exchange Rate Predictability and Financial Conditions...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 13/275: 'Online search behavior and consumer intent: Implications for nowcastin...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 14/275: 'Painting the market: generative diffusion models for financial limit o...'
#   -> Shortlisted! (Interest) Score: 8.0/10
# Processing paper 15/275: 'Taking the Highway or the Green Road? Conditional Temperature Forecast...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 16/275: 'The Economic Value of Weather Forecasts : A Quantitative Systematic Li...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 17/275: 'Context-Aware Language Models for Forecasting Market Impact from Seque...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 18/275: 'Large-Scale Curve Time Series with Common Stochastic Trends...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 19/275: 'Assessing Asymmetric Macroeconomic Risk...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 20/275: 'Dynamic Factor Models with Forward-Looking Views...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 21/275: 'An Interpretable Deep Learning Model for General Insurance Pricing...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 22/275: 'Identifying economic narratives in large text corpora: An integrated a...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 23/275: 'Predicting Market Troughs: A Machine Learning Approach with Causal Int...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 24/275: 'Beyond GARCH: Bayesian Neural Stochastic Volatility...'
#   -> Shortlisted! (Relevant) Score: 9.0/10
# Processing paper 25/275: 'Deep Learning Option Pricing with Market Implied Volatility Surfaces...'
#   -> Shortlisted! (Interest) Score: 8.0/10
# Processing paper 26/275: 'Random Forests for Labor Market Analysis: Balancing Precision and Inte...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 27/275: 'Finance-Grounded Optimization For Algorithmic Trading...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 28/275: 'Deep Learning for Conditional Asset Pricing Models...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 29/275: 'MM-DREX: Multimodal-Driven Dynamic Routing of LLM Experts for Financia...'
#   -> Shortlisted! (Relevant) Score: 9.0/10
# Processing paper 30/275: 'Neural ARFIMA model for forecasting BRIC exchange rates with long memo...'
#   -> Shortlisted! (Relevant) Score: 9.0/10
# Processing paper 31/275: 'DeltaHedge: A Multi-Agent Framework for Portfolio Options Optimization...'
#   -> Shortlisted! (Interest) Score: 7.0/10
# Processing paper 32/275: 'Understanding Patenting Disparities via Causal Human+Machine Learning...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 33/275: 'Governing Synthetic Data in the Financial Sector...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 34/275: 'A Decision Theoretic Perspective on Artificial Superintelligence: Copi...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 35/275: 'Nowcasting Disruptions to Human Capital Formation : Evidence from High...'
#   -> Shortlisted! (Interest) Score: 7.0/10
# Processing paper 36/275: 'Myopic Optimality: why reinforcement learning portfolio management str...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 37/275: 'Breaking the Echo Chamber: Social Media Networks and Political Conflic...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 38/275: 'A survey of statistical arbitrage pair trading with machine learning, ...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 39/275: 'Trading-R1: Financial Trading with LLM Reasoning via Reinforcement Lea...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 40/275: 'Why Bonds Fail Differently? Explainable Multimodal Learning for Multi-...'
#   -> Shortlisted! (Relevant) Score: 9.0/10
# Processing paper 41/275: 'Enhancing ML Models Interpretability for Credit Scoring...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 42/275: 'Deep Learning for Solving Economic Models...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 43/275: 'Benchmarking Machine Learning Models for ESG Prediction in South Korea...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 44/275: 'Demystifying planning application uncertainty: Using machine learning ...'
#   -> Shortlisted! (Interest) Score: 7.0/10
# Processing paper 45/275: 'Enhancing Disaster Evacuation Planning with Cognitive Agent-Based Mode...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 46/275: 'Emergence of pluralistic ignorance: An agent-based approach...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 47/275: 'A Research Agenda for the Economics of Transformative AI...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 48/275: 'Beyond Expert Judgment: An Explainable Framework for Truth Discovery, ...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 49/275: 'Statistical Model Checking of NetLogo Models...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 50/275: 'Qualitative Research in an Era of AI: A Pragmatic Approach to Data Ana...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 51/275: 'Meta-Learning Neural Process for Implied Volatility Surfaces with SABR...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 52/275: 'Estimating National Weather Effects from the Ground Up...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 53/275: 'Adaptive Temporal Fusion Transformers for Cryptocurrency Price Predict...'
#   -> Shortlisted! (Interest) Score: 9.0/10
# Processing paper 54/275: 'Stabilising Lifetime PD Models under Forecast Uncertainty...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 55/275: 'From Courtesy to Influence: Identifying the Role of China’s New Ambass...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 56/275: 'Credit Conditions, Inflation, and Unemployment...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 57/275: 'On the Distributional Effects of Conventional Monetary Policy and Forw...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 58/275: 'Fiscal multiplier in Brazil: the role played by controls...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 59/275: 'Renewable Energy Supply Shocks from Wind Electricity...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 60/275: 'Financial Shocks and the Output Growth Distribution...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 61/275: 'The Signaling Effects of Tightening and Easing Monetary Policy...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 62/275: 'Insuring Labor Income Shocks: The Role of the Dynasty...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 63/275: 'Beyond interbank: Identifying critical participants in integrated RTGS...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 64/275: 'Uneven Waters : Examining Poverty and Urban and Rural Households' Expo...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 65/275: 'Business-as-Usual and Orbital Debris Path...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 66/275: 'Measuring Neighborhood Change: The Issue of Ex Post Borders...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 67/275: 'Measuring hearts and minds: A validated survey module on inequality av...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 68/275: 'Geopolitical Risk and Global Banking...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 69/275: 'There Goes the Neighborhood? The Local Impacts of State Policies That ...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 70/275: 'The Signaling Effects of Tightening and Easing Monetary Policy...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 71/275: 'Stylized facts in money markets: an empirical analysis of the eurozone...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 72/275: 'Firms’ Inflation and Wage Expectations during the Inflation Surge...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 73/275: 'Trade wars and global spillovers. A quantitative assessment with ECB-g...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 74/275: 'Inflation volatility across advanced and emerging economies during the...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 75/275: 'The effects of monetary policy on banks and non-banks in times of stre...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 76/275: 'Monetary policy during Negative Output Gap periods in India in the Fir...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 77/275: 'The overstated effects of conventional monetary policy on output and p...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 78/275: 'Accounting for Uncertainty and Risks in Monetary Policy...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 79/275: 'On the Distributional Effects of Conventional Monetary Policy and Forw...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 80/275: 'Firms’ risk and monetary transmission: revisiting the excess bond prem...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 81/275: 'The Double-Digit Trigger: Estimating Inflation Attention Thresholds in...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 82/275: 'The EU’s New Expenditure Rule and Its Implications for Monetary Policy...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 83/275: 'Dissent in Monetary Policy Decisions: Effects, Channels and Implicatio...'
#   -> Skipped. Score below threshold: 6.0/10
# Processing paper 84/275: 'Central bank preparedness for market-functioning asset purchases as a ...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 85/275: 'Where Collateral Sleeps...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 86/275: 'Credit Conditions, Inflation, and Unemployment...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 87/275: 'Generating the Term Structure of Interest Rates with Diffusion Models...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 88/275: 'Monetary-Fiscal Interactions...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 89/275: 'The Foreign Currency Fisher Channel: Evidence from Households...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 90/275: 'Beyond interbank: Identifying critical participants in integrated RTGS...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 91/275: 'Currency Crises and Malnutrition...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 92/275: 'The ECB-Multi Country Model. A semi-structural model for forecasting a...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 93/275: 'Asset Elasticities and Currency Risk Transfer...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 94/275: 'Seeds of Inflation: Geopolitical Risk and Inflation: The Role of Energ...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 95/275: 'Long-Run Interest Rate Differentials and the Profitability of Currency...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 96/275: 'Testing Evolutionary Theories of Human Cooperation via Meta-Analysis o...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 97/275: 'The Signaling Effects of Tightening and Easing Monetary Policy...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 98/275: 'On the Distributional Effects of Conventional Monetary Policy and Forw...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 99/275: 'Firms’ risk and monetary transmission: revisiting the excess bond prem...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 100/275: 'The effects of monetary policy on banks and non-banks in times of stre...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 101/275: 'The EU’s New Expenditure Rule and Its Implications for Monetary Policy...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 102/275: 'Monetary policy during Negative Output Gap periods in India in the Fir...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 103/275: 'Trade wars and global spillovers. A quantitative assessment with ECB-g...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 104/275: 'The ECB-Multi Country Model. A semi-structural model for forecasting a...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 105/275: 'Central bank preparedness for market-functioning asset purchases as a ...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 106/275: 'Bailouts and Redistribution...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 107/275: 'Financial Shocks and the Output Growth Distribution...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 108/275: 'Generating the Term Structure of Interest Rates with Diffusion Models...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 109/275: 'Monetary-Fiscal Interactions...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 110/275: 'Beyond interbank: Identifying critical participants in integrated RTGS...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 111/275: 'A Research Agenda for the Economics of Transformative AI...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 112/275: 'Territorial Control of Data and Compute in Generative AI: A New Paradi...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 113/275: 'Artificial Intelligence in Team Dynamics: Who Gets Replaced and Why?...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 114/275: 'Do Markets Believe in Transformative AI?...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 115/275: 'Trading-R1: Financial Trading with LLM Reasoning via Reinforcement Lea...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 116/275: 'Geopolitical Risk and Global Banking...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 117/275: 'Asset Elasticities and Currency Risk Transfer...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 118/275: 'The Foreign Currency Fisher Channel: Evidence from Households...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 119/275: 'Oil shocks and firm investment on the two sides of the Atlantic...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 120/275: 'The Signaling Effects of Tightening and Easing Monetary Policy...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 121/275: 'Estimating National Weather Effects from the Ground Up...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 122/275: 'Where Collateral Sleeps...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 123/275: 'Efficiency Costs of Incomplete Markets...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 124/275: 'Trade wars and global spillovers. A quantitative assessment with ECB-g...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 125/275: 'Seeds of Inflation: Geopolitical Risk and Inflation: The Role of Energ...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 126/275: 'The Changing Nature of International Trade and its Implications for De...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 127/275: 'Do Markets Believe in Transformative AI?...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 128/275: 'Asset-price redistribution...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 129/275: 'Imperfect Banking Competition and the Propagation of Uncertainty Shock...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 130/275: 'Pricing Tail Risks: Bank Equity Returns During the 2023 Bank Stress...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 131/275: 'Does Pair Trading Still Work During Extreme Events? A Comprehensive Em...'
#   -> Shortlisted! (Relevant) Score: 7.0/10
# Processing paper 132/275: 'Geopolitical Risk and Global Banking...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 133/275: 'Tail Connectedness Between Robotics and AI ETFs and Traditional Us Ass...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 134/275: 'The Interplay between Utility and Risk in Portfolio Selection...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 135/275: 'Geopolitical Risks and Trade...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 136/275: 'Why Bonds Fail Differently? Explainable Multimodal Learning for Multi-...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 137/275: 'Assessing Asymmetric Macroeconomic Risk...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 138/275: 'Meta-Learning Neural Process for Implied Volatility Surfaces with SABR...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 139/275: 'Enhancing ML Models Interpretability for Credit Scoring...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 140/275: 'Firms’ risk and monetary transmission: revisiting the excess bond prem...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 141/275: 'Asset Elasticities and Currency Risk Transfer...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 142/275: 'Pricing Tail Risks: Bank Equity Returns During the 2023 Bank Stress...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 143/275: 'Simulating the Resilience of the Canadian Banking Sector Under Stress:...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 144/275: 'Does Pair Trading Still Work During Extreme Events? A Comprehensive Em...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 145/275: 'Optimal Balance Between Funding and Payg Pensions: the Case of NDC Pen...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 146/275: 'A core multi-criteria framework for assessing the performance of polic...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 147/275: 'Group Survival Probability under Contagion in Microlending...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 148/275: 'Is There a Puzzle in Underwater Mortgage Default?...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 149/275: 'Beyond Expert Judgment: An Explainable Framework for Truth Discovery, ...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 150/275: 'Local Resistance to International High-Speed Rail Projects – Lessons f...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 151/275: 'Unveiling the impact of geopolitical risk, climate policy uncertainty,...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 152/275: 'Green Finance and Deforestation Reduction in Brazil: a PVAR Analysis o...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 153/275: 'AI Business Applications Training and Business Outcomes: An Inclusive ...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 154/275: 'Unpacking the Distributional Implications of the Energy Crisis: Lesson...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 155/275: 'Exploring the feasibility of low-carbon fuel blends in CCGTs for deep ...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 156/275: 'Competition Between Green and Blue Hydrogen and Indirect Network Effec...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 157/275: 'Economic development, carbon emissions and climate policies...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 158/275: 'Trade and the Scopes of Pollution: Evidence from China’s World Market ...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 159/275: 'Uncertainty in climate policy and energy industry...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 160/275: 'The National Carbon Price and Welfare on Alternative Paths Towards Net...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 161/275: 'Carbon taxation and precautionary savings...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 162/275: 'A Linear Pricing Mechanism for Load Management in Day-Ahead Retail Ene...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 163/275: 'Heterogeneous and dynamic pass-through of a fuel subsidy to consumers:...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 164/275: 'Taking the Highway or the Green Road? Conditional Temperature Forecast...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 165/275: 'Imperfect Competition and the Adoption of Clean Technology: The Case o...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 166/275: 'Demand for Green Skills in an Evolving Landscape...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 167/275: 'Critical Iridium Demands arising from future Expansion of Proton Excha...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 168/275: 'Smart Power Limits: Designing Shortage Mechanisms for Extreme Events...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 169/275: 'Land concentration and large renewable energy projects...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 170/275: 'How OPEC Oil Shocks Shape U.S. CPI Inflation: Evidence from an IV-SVAR...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 171/275: 'Reconciling Eco and Ego? The Interplay Between Environmental and Image...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 172/275: 'Who Pays for Climate Policy? Distributional Narratives and Populist Ba...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 173/275: 'Geopolitical Risk and Extreme Spillovers Among Oil-Based Energy Commod...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 174/275: 'Heads Up : Does Air Pollution Cause workplace Accidents?...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 175/275: 'Environmental Summits and Innovation...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 176/275: 'Macroeconomic Exposure to the EU’s Carbon Border Adjustment Mechanism:...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 177/275: 'A Model For Teaching Oil Shocks In A Small, Open, Oil-Exporting, And D...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 178/275: 'Firm Ownership and Pollution...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 179/275: 'Der Einfluss von beruflicher Ähnlichkeit und Arbeitsmarktbedingungen a...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 180/275: 'Citizen Training and the Urban Waste Footprint...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 181/275: 'Demand for Green Skills in an Evolving Landscape...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 182/275: 'Air Quality and Conferencesâ€™ Engagement...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 183/275: 'FEDS Paper: Illiquid Homeownership and the Bank of Mom and Dad...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 184/275: 'FEDS Paper: “Harvest Now Decrypt Later”: Examining Post-Quantum Crypto...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 185/275: 'FEDS Paper: Can LLMs Improve Sanctions Screening in the Financial Syst...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 186/275: 'FEDS Paper: Parallel Trends Forest: Data-Driven Control Sample Selecti...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 187/275: 'FEDS Paper: Financial Stability Implications of Generative AI: Taming ...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 188/275: 'IFDP Paper: Imperfect Information and Slow Recoveries in the Labor Mar...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 189/275: 'IFDP Paper: Clean Money, High Costs?...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 190/275: 'FEDS Paper: Virtue or Mirage? Complexity in Exchange Rate Prediction...'
#   -> Shortlisted! (Relevant) Score: 7.0/10
# Processing paper 191/275: 'FEDS Paper: Automated Credit Limit Increases and Consumer Welfare...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 192/275: 'IFDP Paper: Core Inflation in the Advanced Economies: A Regional Persp...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 193/275: 'FEDS Paper: One Policy Rate, Many Stances: Evidence from the European ...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 194/275: 'FEDS Paper: Where's The Bank? Banking Access in the Era of Branch Cons...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 195/275: 'FEDS Paper: Non-homothetic Demand Shifts and Inflation Inequality...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 196/275: 'FEDS Paper: Attention-Dependent Monetary Transmission to Household Bel...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 197/275: 'FEDS Paper: Monetary Policy and Bank Funding Costs: Patterns and Predi...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 198/275: 'Macroprudential policy, monetary policy and non-bank financial interme...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 199/275: 'Hidden weaknesses: the role of unrealized losses in monetary policy tr...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 200/275: 'The impact of capital requirements on bank capital...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 201/275: 'Durability, essentiality, and the transmission of monetary policy to h...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 202/275: 'Foreign demand for safety and macroeconomic instability...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 203/275: 'Battle of the ages: distributional and aggregate effects of monetary p...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 204/275: 'The Great Moderation at 40: learning from the cross section...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 205/275: 'Business cycles with pricing cascades...'
#   -> Skipped. Score below threshold: 6.0/10
# Processing paper 206/275: 'Letter from the ECB President to Mr Fabio De Masi, MEP, on monetary po...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 207/275: 'Letter from Piero Cipollone to Aurore Lalucq, ECON Chair, on the digit...'
#   -> Skipped. Score below threshold: 1.0/10
# Processing paper 208/275: 'What can newspaper articles reveal about the euro area economy?...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 209/275: 'Heterogeneity in macroeconomics...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 210/275: 'Economic Bulletin Issue 6, 2025...'
#   -> Skipped. Score below threshold: 1.0/10
# Processing paper 211/275: 'Macroeconomic impacts of higher defence spending: a model-based assess...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 212/275: 'Liquidity conditions and monetary policy operations from 23 April to 2...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 213/275: 'State Capacity, Institutions and Growth: Taxing for Takeoff—Revisiting...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 214/275: 'Fiscal Rules and Fiscal Councils: Recent Trends and Revisions since th...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 215/275: 'Recycling Risk: Synthetic Risk Transfers...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 216/275: 'External Shocks and Monetary Policy Trade-offs in Low-Income Countries...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 217/275: 'Restructuring Sovereign Domestic Debt in Developing Countries...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 218/275: 'The Effects of Fiscal Consolidations on the Debt Distribution...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 219/275: 'AI Projects in Financial Supervisory Authorities...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 220/275: 'Credit where Credit is Due: Fiscal Consolidations, Sovereign Risk and ...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 221/275: 'Monetary Policy and Housing Overvaluation...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 222/275: 'State Fragility: Towards a Conceptual Framework...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 223/275: 'The capital puzzle...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 224/275: 'Banks' regulatory risk tolerance...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 225/275: 'How do quantitative easing and tightening affect firms?...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 226/275: 'DP20704 Decomposing Comparative Development 1880-2020: A Quantitative ...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 227/275: 'DP20708 Demand steering through the smokescreen of stockouts: evidence...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 228/275: 'DP20705 Conflict and Investment:  A Review Across Health, Fertility, E...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 229/275: 'DP20707 Drivers of Switching in Autoinsurance: Evidence from observabl...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 230/275: 'DP20706 Gender Gaps in Patience, Risk-Taking, Trust, and Prosociality ...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 231/275: 'DP20700 Two-Sided Market Pricing with Heterogeneous Users: Theory and ...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 232/275: 'DP20702 Disclosure, Patenting, and Trade Secrecy...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 233/275: 'DP20701 Skill Disruption and Post-Acquisition Employee Exit...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 234/275: 'DP20703 Auctions vs. Negotiations: The Role of the Payment Structure...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 235/275: 'DP20699 Public-Private Partnerships, Asymmetric Information, and Incom...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 236/275: 'DP20697 Work Intensity and Welfare Across Countries and Over Time...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 237/275: 'DP20698 Ambiguity and the Variance of Gambles...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 238/275: 'DP20694 Sources of consumer information...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 239/275: 'DP20689 For Better or for Babies: Fertility Constraints and Marriage i...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 240/275: 'DP20696 Left Over or Opting Out? Squeeze, Mismatch and Surplus in Chin...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 241/275: 'DP20690 Export Controls and Innovation in Sanctioned Countries...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 242/275: 'DP20695 The Impact of Interest: Firms' Investment Sensitivity to Inter...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 243/275: 'DP20691 Labor Markets, Financial Crises, and Inflation: Jobless and Wa...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 244/275: 'DP20692 The Causal Effect of Parents' Education on Children's Earnings...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 245/275: 'DP20693 Investing in Human Capital During Wartime: Experimental Eviden...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 246/275: 'DP20683 Bridging Quasi-Experimental and Structural Approaches for Robu...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 247/275: 'DP20688 Demographic Trends and Government Debt Dynamics in the US and ...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 248/275: 'DP20685 The Labor Market Consequences of Acquisitions...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 249/275: 'DP20687 The Inflationary Footprint of Fiscal Policy: Evidence from Dis...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 250/275: 'DP20686 Data, Power and Emissions: The Environmental Cost of AI...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 251/275: 'DP20684 Financial Value of Nature:  Coastal Housing Markets, Mangroves...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 252/275: 'DP20681 Ex Machina: Financial Stability in the Age of Artificial Intel...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 253/275: 'DP20682 Political Polarization and Human Capital Allocation...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 254/275: 'DP20679 Global Trends in Innovation Patterns: A Complexity Approach...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 255/275: 'DP20680 FCI-Plot: Central Bank Communication Through Financial Conditi...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 256/275: 'DP20678 Innovation Policies Under Economic Complexity...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 257/275: 'DP20677 Tariffs as Fiscal Policy...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 258/275: 'DP20676 Air Quality and Conferences' Engagement...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 259/275: 'DP20673 Incorporating Non-Unitary Income Elasticities, Choke Prices an...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 260/275: 'DP20672 A Nascent International Financial Channel of China’s Monetary ...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 261/275: 'DP20675 Systemic Cyber Risk: Linking Measurement, Market Incentives, a...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 262/275: 'DP20674 Specialization in Banking...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 263/275: 'DP20669 Deep Learning for Solving Economic Models...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 264/275: 'DP20668 Gatekeepers and Self-Preferencing: Incentives and Welfare Trad...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 265/275: 'DP20671 Human Capital Accumulation Across Space...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 266/275: 'DP20670 A New Approach to Fiscal Multipliers: Time Variation and High ...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 267/275: 'DP20661 An Empirical Investigation of the Effects of Monetary Policy S...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 268/275: 'DP20667 Equity Frictions and Firm Ownership...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 269/275: 'DP20665 Asset Elasticities and Currency Risk Transfer...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 270/275: 'DP20660 Do Billionaires Pay Taxes?...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 271/275: 'DP20662 Nature and Biodiversity Loss: A Research Agenda for Financial ...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 272/275: 'DP20663 Identity as Self-Image...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 273/275: 'DP20664 Playing with Blocs: Quantifying Decoupling...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 274/275: 'DP20666 Multigenerational Inequality...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 275/275: 'DP20659 Macroeconomics and Climate Change...'
#   -> Skipped. Score below threshold: 2.0/10
# ✅ Internal review file saved: newsletters/ets4_monthly_2025-10-05_INTERNAL.md
# ✅ Public newsletter file saved: newsletters/ets4_monthly_2025-10-05_PUBLIC.md
#
# --- Pipeline Finished ---
# Total unique papers processed by LLM: 275
# Shortlisted 56 'Directly Relevant' papers.
# Shortlisted 7 'Papers of Interest'.
