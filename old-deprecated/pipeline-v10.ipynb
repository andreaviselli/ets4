# %%
import feedparser
from openai import OpenAI
import datetime
from dateutil import parser as dateparser
import json
import requests
import os
import re # Import regex for creating anchor slugs
from bs4 import BeautifulSoup # For cleaning HTML from summaries
from dotenv import load_dotenv

# ------------- CONFIG ----------------

# Load environment variables from .env file (must be in the same directory)
load_dotenv()

# Configuration
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
if not OPENAI_API_KEY:
	raise ValueError("OPENAI_API_KEY not found. Make sure it's set in your .env file.")

# Use the modern OpenAI client
client = OpenAI(api_key=OPENAI_API_KEY)

# Using gpt-4o-mini: faster, more capable, and cost-effective for this task.
LLM_MODEL = "gpt-4o-mini"

SCORE_THRESHOLD = 8.0  # Keep only papers scoring above this
DAYS_BACK = 10#30         # Look back this many days
OUTPUT_DIR = "newsletters"

# --- User-Curated RSS Feeds ---
RSS_FEEDS = {
    # NEP - Economics
    "NEP-FOR": "https://nep.repec.org/rss/nep-for.rss.xml",   # **Forecasting** (Most Important)
    "NEP-ETS": "https://nep.repec.org/rss/nep-ets.rss.xml",   # Econometric Time Series
    "NEP-BIG": "https://nep.repec.org/rss/nep-big.rss.xml",   # Big Data
    "NEP-CMP": "https://nep.repec.org/rss/nep-cmp.rss.xml",   # Computational Economics
    "NEP-MAC": "https://nep.repec.org/rss/nep-mac.rss.xml",   # Macroeconomics
    "NEP-MON": "https://nep.repec.org/rss/nep-mon.rss.xml",   # Monetary Economics
    "NEP-MFD": "https://nep.repec.org/rss/nep-mfd.rss.xml",   # Macrofinance
    "NEP-CBA": "https://nep.repec.org/rss/nep-cba.rss.xml",   # Central Banking
    "NEP-AIN": "https://nep.repec.org/rss/nep-ain.rss.xml",   # Artificial Intelligence
    "NEP-CBE": "https://nep.repec.org/rss/nep-cbe.rss.xml",   # Cognitive and Behavioral Economics
    
    # NEP - Finance
    "NEP-FMK": "https://nep.repec.org/rss/nep-fmk.rss.xml",   # Financial Markets
    "NEP-RMG": "https://nep.repec.org/rss/nep-rmg.rss.xml",   # Risk Management
    "NEP-PPM": "https://nep.repec.org/rss/nep-ppm.rss.xml",   # Project, Program and Portfolio Management
    "NEP-IFN": "https://nep.repec.org/rss/nep-ifn.rss.xml",   # International Finance

    # NEP - Energy & Resource Focused
    "NEP-ENE": "https://nep.repec.org/rss/nep-ene.rss.xml",   # Energy Economics
    "NEP-RES": "https://nep.repec.org/rss/nep-res.rss.xml",   # Resource Economics

    # ArXiv - Core Quantitative & CS Fields
    "arXiv-econEM": "http://export.arxiv.org/rss/econ.EM",     # Econometrics
    "arXiv-econGM": "http://export.arxiv.org/rss/econ.GM",     # General Economics
    "arXiv-statML": "http://export.arxiv.org/rss/stat.ML",     # Statistics - Machine Learning
    "arXiv-statAP": "http://export.arxiv.org/rss/stat.AP",     # Statistics - Applications
    "arXiv-csLG": "http://export.arxiv.org/rss/cs.LG",         # Computer Science - Machine Learning
    "arXiv-csAI": "http://export.arxiv.org/rss/cs.AI",         # Computer Science - Artificial Intelligence
    "arXiv-csCY": "http://export.arxiv.org/rss/cs.CY",         # Computer and Society
    "arXiv-qFIN-ST": "http://export.arxiv.org/rss/q-fin.ST",   # Quantitative Finance - Statistical Methods
    "arXiv-qFIN-CP": "http://export.arxiv.org/rss/q-fin.CP",   # Quantitative Finance - Computational Finance
    "arXiv-qFIN-PM": "http://export.arxiv.org/rss/q-fin.PM",   # Quantitative Finance - Computational Finance

    # High-Signal Institutions (Central Banks & Academic Orgs)
    "FEDS_Papers": "https://www.federalreserve.gov/feeds/working_papers.xml",     # US Federal Reserve Board
    "FEDS2_Papers": "https://www.federalreserve.gov/feeds/feds.xml",              # US FED Finance & Economics Discussion Series
    "NYDEB_Papers": "https://www.newyorkfed.org/research/rss/feeds/epr.xml",      # New York FED Economic Policy Review
    "NBER_Papers": "https://www.nber.org/rss/new.xml",                            # National Bureau of Economic Research
    "ECB_Papers": "https://www.ecb.europa.eu/rss/pub.html",                       # European Central Bank
    "IMF_Papers": "https://www.imf.org/en/Publications/RSS?language=eng&series=IMF%20Working%20Papers", # International Monetary Fund
    "BIS_Papers": "https://www.bis.org/doclist/bis_fsi_publs.rss",                # Bank for International Settlements
    "CEPR_Papers": "https://cepr.org/rss/discussion-paper",                       # Centre for Economic Policy Research (CEPR)
    "VoxEU_Papers": "https://voxeu.org/rss.xml",                                  # VoxEU Research Articles
    "BOE_Papers": "https://www.bankofengland.co.uk/rss/publications",                 # Bank of England Research
}

# ------------- HELPER FUNCTIONS ----------------

def _get_authors(entry):
    """Normalizes author information from a feed entry."""
    if hasattr(entry, 'authors') and entry.authors:
        return ', '.join(author['name'] for author in entry.authors if 'name' in author)
    if hasattr(entry, 'author'):
        return entry.author
    return "Unknown"

def _create_anchor_slug(title, index):
    """Creates a URL-friendly slug from a title for anchor links."""
    s = title.lower()
    s = re.sub(r'[^\w\s-]', '', s) # Remove non-alphanumeric characters
    s = re.sub(r'[\s_-]+', '-', s).strip('-') # Replace spaces with hyphens
    return f"{s}-{index}"

# ------------- CORE FUNCTIONS ----------------

def fetch_recent_papers():
    """Fetch recent papers from RSS feeds with robust date parsing and encoding correction."""
    print(f"Fetching papers from {len(RSS_FEEDS)} sources, looking back {DAYS_BACK} days...")
    cutoff_date = datetime.datetime.now(datetime.timezone.utc) - datetime.timedelta(days=DAYS_BACK)
    papers = []

    for source, url in RSS_FEEDS.items():
        print(f"  - Processing {source} from {url}")
        try:
            response = requests.get(url, timeout=15)
            if "utf-8" in response.text.lower() or "<?xml" in response.text:
                response.encoding = "utf-8"
            feed = feedparser.parse(response.text)
            if feed.bozo:
                print(f"    Warning: Malformed feed for {source}. Error: {feed.bozo_exception}")

            found_in_feed = 0
            for entry in feed.entries:
                pub_date_str = getattr(entry, "published", getattr(entry, "updated", None))
                if not pub_date_str: continue
                try:
                    pub_date = dateparser.parse(pub_date_str)
                except dateparser.ParserError:
                    continue
                if pub_date.tzinfo is None:
                    pub_date = pub_date.replace(tzinfo=datetime.timezone.utc)
                if pub_date < cutoff_date: continue
                summary = getattr(entry, "summary", "")
                if "<" in summary and ">" in summary:
                    summary = BeautifulSoup(summary, "html.parser").get_text(separator=' ', strip=True)
                papers.append({
                    "title": entry.title, "link": entry.link, "summary": summary,
                    "authors": _get_authors(entry), "source": source, "date": pub_date.strftime("%Y-%m-%d")
                })
                found_in_feed += 1
            print(f"    Found {found_in_feed} recent papers in {source}.")
        except Exception as e:
            print(f"    Error fetching or parsing feed {source}: {e}")
            continue
    return papers

def score_and_summarize(paper):
    """Sends abstract to LLM for summary, scoring, and categorization."""
    prompt = f"""
You are a highly specialized econometrician and economic forecaster curating "ets4 Monthly (Economic Time Series Forecasting Monthly)", a customized newsletter focused **exclusively on impactful forecasting methods suitable for economic time series.** Your role is to identify only the most relevant and innovative work for an audience of researchers and practitioners that includes econometricians, macroeconomists, energy economists, financial economists and all professionals that are interested in innovative forecasting methods.

You will be given a research working paper. Evaluate it strictly through the lens of **forecasting relevance, innovative content, and potential. In particular, **papers that focus on topics** such as structural analysis and/or causal inference (i.e., structural vector autoregressions for dynamic causal analysis, and causal inference with cross-sections), descriptive statistics and/or econometrics, purely theoretical econometrics and applied economics with no clear and unique forecasting objective and components must be classified as **Not Relevant**, even if they appear in economics journals or are effectively innovative.

---

**Paper Information**

Title: {paper['title']}
Authors: {paper['authors']}
Source: {paper['source']}
Date: {paper['date']}
Abstract: {paper['summary']}

---

### Your Tasks

1. **Summarize (4–5 sentences)**  
   Focus strictly on elements related to **forecasting and predictive modeling** as stated or clearly implied in the abstract. Because you only see the abstract, avoid inventing or assuming forecasting details unless explicitly mentioned.  
   - If forecasting, prediction, or nowcasting is **explicitly mentioned**, summarize only those components (methods, data, evaluation).  
   - If forecasting is **implied but not directly stated**, clearly indicate this uncertainty (e.g., “the abstract suggests but does not confirm a forecasting application”).  
   - If forecasting is **absent**, explicitly state that no forecasting content is presented.  
   Clearly explain **what is technically or conceptually novel**, but only when the abstract provides enough information to support such statements.

2. **Assign a Quality Score (1–10)**  
      Score based on **forecasting methodological or data novelty, empirical rigor, clarity of predictive purpose, and potential impact or interest for the forecasting community**. Since only the abstract is available, be conservative: give higher scores only when forecasting content is unambiguous.
   - **Extra weight should be given** to papers that:
     - Introduce **new modeling/methodological approaches** or **improve existing ones**. Some examples are, in particular, the use of machine learning/deep learning methods, large language models and generative AI methods, Bayesian methods, novel time series models, forecast combination methods (including Bayesian model averaging), advanced econometric techniques specifically designed for forecasting for policy-relevant macro-financial-economic applications, forecast evaluation such as statistical predictive ability tests and scoring rules, and methods for handling real-time data issues (e.g., ragged edges, mixed frequencies, and data revisions), judgemental forecasting methods, human-AI collaboration for forecasting, study of forecast biases, and interpretability/explainability of forecasts, feature engineering, methods to quantify and improve forecast uncertainty.
     - Use **novel datasets** that could meaningfully enhance economic forecasting. Some examples are, in particular, the use of high-frequency data, alternative data sources (e.g., web-scraped data, satellite data, social media data, news sentiment data, mobility data, transaction data), large-scale datasets, real-time datasets, and data from large language models or other generative AI systems.
     - Present **forecasting applications with real-world decision value**. Some examples are, in particular, the forecasting (and nowcasting) of GDP and inflation, energy prices and demand (including gas, oil, commodities, and electricity), asset prices (including stocks, bonds, interest rates, and crypto), and financial risks (including volatility and default risk).

3. **Classify into One Category**  
   Choose exactly one:
   - **Directly Relevant** → The paper is clearly about **forecasting *economic* time series**, has some of the elements presented above, and offers meaningful contributions or applications although the innovation might not be significant (this is to select also papers that are solid and interesting but not necessarily groundbreaking or highly novel).
   - **Paper of Interest** → The paper is *not economic*, but presents **highly innovative forecasting methods or data sources/types** that could be plausibly transferred to the forecasting of economic time series with some adaptation. Explain briefly how this could be done in the `"adaptability_reason"` field of the JSON output.
   - **Not Relevant** → No clear link with forecasting, or relevance is too indirect (e.g., see the list that is made above).

---

### Scoring & Categorization Rules

| Score | Meaning | Default Category |
|--------|---------|------------------|
| **1–3** | Low quality OR no forecasting at all | Not Relevant |
| **4–6** | Little forecasting contribution and low general quality | Not Relevant |
| **7–8** | Solid contribution to forecasting | Directly Relevant *if economic*, otherwise Paper of Interest |
| **9–10** | Novel forecasting contribution with clear future impact | Directly Relevant *if economic*, otherwise Paper of Interest |

---

### JSON Output Format

Return your response strictly in **valid JSON** using the following schema:

{{
"summary": "...",
"score": X,
"category": "Directly Relevant" | "Paper of Interest" | "Not Relevant",
"adaptability_reason": null | "Required only if category is 'Paper of Interest'"
}}

- If you select **Paper of Interest**, you **must** fill in `"adaptability_reason"` with a short statement explaining how the method could be applied to economic forecasting.
- For **Directly Relevant** or **Not Relevant**, set `"adaptability_reason": null`.
"""
    try:
        response = client.chat.completions.create(
            model=LLM_MODEL,
            messages=[{"role": "user", "content": prompt}],
            temperature=0.2,
            response_format={"type": "json_object"}
        )
        content = response.choices[0].message.content
        data = json.loads(content)
        required_keys = ["summary", "score", "category", "adaptability_reason"]
        if not all(key in data for key in required_keys):
            raise ValueError(f"LLM response missing one or more required keys: {required_keys}")
        if not isinstance(data["score"], (int, float)):
            raise ValueError("LLM score is not a number.")
        if data["category"] == "Paper of Interest" and not data.get("adaptability_reason"):
            raise ValueError("Category is 'Paper of Interest' but adaptability_reason is missing.")
        data["score"] = float(data["score"])
        return data
    except Exception as e:
        print(f"Error during LLM call for paper '{paper['title']}': {e}")
        return {"summary": f"Error: {e}", "score": 0.0, "category": "Not Relevant", "adaptability_reason": None}
    
def _create_anchor_slug(title):
    """Creates a Markdown-compatible anchor slug from a title."""
    s = title.lower()
    s = re.sub(r'[^\w\s-]', '', s) # Remove non-alphanumeric characters
    s = re.sub(r'[\s_]+', '-', s).strip('-') # Replace spaces with a single hyphen
    return s

def build_internal_markdown(relevant_papers, interest_papers, filename):
    """Creates the internal markdown file WITH scores for review."""
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    today_str = datetime.date.today().strftime('%Y-%m-%d')
    lines = [f"# ets4 Monthly [INTERNAL] – {today_str}\n", "Internal review copy with quality scores.\n"]
    lines.append("## Directly Relevant Papers\n")
    if not relevant_papers:
        lines.append("No directly relevant papers met the criteria this month.\n")
    else:
        relevant_papers.sort(key=lambda p: p['score'], reverse=True)
        for p in relevant_papers:
            lines.append(f"### [{p['title']}]({p['link']})")
            lines.append(f"- **Authors:** {p['authors']}")
            lines.append(f"- **Source:** {p['source']} ({p['date']})")
            lines.append(f"- **Quality Score:** {p['score']:.1f}/10")
            lines.append(f"- **Summary:** {p['summary']}\n")
    lines.append("\n---\n")
    lines.append("## Papers of Interest\n")
    if not interest_papers:
        lines.append("No papers of interest were identified this month.\n")
    else:
        interest_papers.sort(key=lambda p: p['score'], reverse=True)
        for p in interest_papers:
            lines.append(f"### [{p['title']}]({p['link']})")
            lines.append(f"- **Authors:** {p['authors']}")
            lines.append(f"- **Source:** {p['source']} ({p['date']})")
            lines.append(f"- **Quality Score:** {p['score']:.1f}/10")
            lines.append(f"- **Summary:** {p['summary']}")
            lines.append(f"- **Reason for Interest:** {p.get('adaptability_reason', 'N/A')}\n")
    with open(filename, "w", encoding="utf-8") as f:
        f.write("\n".join(lines))
    print(f"✅ Internal review file saved: {filename}")

def build_public_markdown(relevant_papers, interest_papers, filename):
    """Creates the public-facing markdown file with the user-specified clean format."""
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    today = datetime.date.today()
    
    # --- Generate all required date formats ---
    iso_date_str = today.strftime('%Y-%m-%d')
    # FIX: Format for the main body header, e.g., "October 13, 2025"
    main_header_date_str = today.strftime('%B %d, %Y') 
    # FIX: Format for the front matter title, e.g., "October 2025"
    front_matter_date_str = today.strftime('%B %Y')

    # --- Construct the Hugo front matter with the correct title format ---
    front_matter = f"""---
title: "ets4: {front_matter_date_str} Issue"
date: {iso_date_str}
draft: true
toc: false
---
"""
    # --- Construct the main header with the correct title format and add spacing ---
    lines = [
        front_matter,
        f"# ets4: {main_header_date_str}\n",
        "\n&nbsp;\n" # Add spacing
    ]

    # --- Deduplicate and Sort Papers ---
    seen_titles = set()
    unique_relevant = []
    for p in sorted(relevant_papers, key=lambda x: x['score'], reverse=True):
        normalized_title = ' '.join(p['title'].lower().split())
        if normalized_title not in seen_titles:
            unique_relevant.append(p)
            seen_titles.add(normalized_title)

    unique_interest = []
    for p in sorted(interest_papers, key=lambda x: x['score'], reverse=True):
        normalized_title = ' '.join(p['title'].lower().split())
        if normalized_title not in seen_titles:
            unique_interest.append(p)
            seen_titles.add(normalized_title)

    # --- Build "Directly Relevant Papers" Section ---
    if unique_relevant:
        lines.append("## Directly Relevant Papers\n")
        lines.append("A curated list of recent papers on novel methods for forecasting economic time series.\n")
        lines.append("**In this Issue**\n")
        for p in unique_relevant:
            anchor = _create_anchor_slug(p['title'])
            lines.append(f"* [{p['title']}](#{anchor})")
        lines.append("")

    # --- Build "Papers of Interest" Section ---
    if unique_interest:
        lines.append("\n---\n")
        lines.append("## Papers of Interest\n")
        lines.append("_Methodologically novel papers from other fields that could be adapted for economic forecasting._\n")
        lines.append("**In this Issue**\n")
        for p in unique_interest:
            anchor = _create_anchor_slug(p['title'])
            lines.append(f"* [{p['title']}](#{anchor})")
        lines.append("")

    # --- Build "Paper Details" for Relevant Papers ---
    if unique_relevant:
        lines.append("\n&nbsp;\n")
        lines.append("\n---\n")
        for p in unique_relevant:
            lines.append(f"## {p['title']}")
            lines.append(f"[Link to working paper ↗]({p['link']})\n")
            lines.append(f"- **Authors:** {p['authors']}")
            lines.append(f"- **Source:** {p['source']} ({p['date']})")
            lines.append(f"- **Summary:** {p['summary']}")
            lines.append("\n&nbsp;\n")

    # --- Build "Paper Details" for Interest Papers ---
    if unique_interest:
        lines.append("\n---\n")
        lines.append("\n&nbsp;\n")
        for p in unique_interest:
            lines.append(f"## {p['title']}")
            lines.append(f"[Link to working paper ↗]({p['link']})\n")
            lines.append(f"- **Authors:** {p['authors']}")
            lines.append(f"- **Source:** {p['source']} ({p['date']})")
            lines.append(f"- **Summary:** {p['summary']}")
            lines.append(f"- **Reason for Interest:** {p.get('adaptability_reason', 'N/A')}")
            lines.append("\n&nbsp;\n")

    if not unique_relevant and not unique_interest:
        lines.append("## No papers met the criteria this month. Check back soon!\n")
        
    with open(filename, "w", encoding="utf-8") as f:
        f.write("\n".join(lines))
    print(f"✅ Public newsletter file saved: {filename}")


# ------------- MAIN ----------------

if __name__ == "__main__":
    print("Starting Economic Forecasting Newsletter Pipeline...")
    all_papers = fetch_recent_papers()
    print(f"Found {len(all_papers)} total recent papers.")
    unique_papers = []
    seen_links = set()
    for paper in all_papers:
        if paper['link'] not in seen_links:
            unique_papers.append(paper)
            seen_links.add(paper['link'])
    if len(all_papers) > len(unique_papers):
        print(f"Removed {len(all_papers) - len(unique_papers)} link-based duplicates. Processing {len(unique_papers)} unique papers.")
    
    shortlisted_relevant = []
    shortlisted_interest = []
    for i, paper in enumerate(unique_papers, 1):
        print(f"Processing paper {i}/{len(unique_papers)}: '{paper['title'][:70]}...'")
        result = score_and_summarize(paper)
        paper.update(result)
        if paper.get("score", 0.0) >= SCORE_THRESHOLD:
            if paper.get("category") == "Directly Relevant":
                shortlisted_relevant.append(paper)
                print(f"  -> Shortlisted! (Relevant) Score: {paper['score']:.1f}/10")
            elif paper.get("category") == "Paper of Interest":
                shortlisted_interest.append(paper)
                print(f"  -> Shortlisted! (Interest) Score: {paper['score']:.1f}/10")
            else:
                print(f"  -> Skipped. Category: {paper.get('category', 'Unknown')}, Score: {paper['score']:.1f}/10")
        else:
            print(f"  -> Skipped. Score below threshold: {paper.get('score', 0.0):.1f}/10")
    
    today_str = datetime.date.today().strftime("%Y-%m-%d")
    internal_filename = os.path.join(OUTPUT_DIR, f"{today_str}_ets4_monthly_INTERNAL.md")
    public_filename = os.path.join(OUTPUT_DIR, f"{today_str}_ets4_monthly_PUBLIC.md")
    
    build_internal_markdown(shortlisted_relevant, shortlisted_interest, internal_filename)
    build_public_markdown(shortlisted_relevant, shortlisted_interest, public_filename)
    
    print("\n--- Pipeline Finished ---")
    print(f"Total unique papers processed by LLM: {len(unique_papers)}")
    print(f"Shortlisted {len(shortlisted_relevant)} 'Directly Relevant' papers.")
    print(f"Shortlisted {len(shortlisted_interest)} 'Papers of Interest'.")
# Out:
# Starting Economic Forecasting Newsletter Pipeline...
# Fetching papers from 32 sources, looking back 10 days...
#   - Processing NEP-FOR from https://nep.repec.org/rss/nep-for.rss.xml
#     Found 5 recent papers in NEP-FOR.
#   - Processing NEP-ETS from https://nep.repec.org/rss/nep-ets.rss.xml
#     Found 12 recent papers in NEP-ETS.
#   - Processing NEP-BIG from https://nep.repec.org/rss/nep-big.rss.xml
#     Found 4 recent papers in NEP-BIG.
#   - Processing NEP-CMP from https://nep.repec.org/rss/nep-cmp.rss.xml
#     Found 8 recent papers in NEP-CMP.
#   - Processing NEP-MAC from https://nep.repec.org/rss/nep-mac.rss.xml
#     Found 16 recent papers in NEP-MAC.
#   - Processing NEP-MON from https://nep.repec.org/rss/nep-mon.rss.xml
#     Found 13 recent papers in NEP-MON.
#   - Processing NEP-MFD from https://nep.repec.org/rss/nep-mfd.rss.xml
#     Found 0 recent papers in NEP-MFD.
#   - Processing NEP-CBA from https://nep.repec.org/rss/nep-cba.rss.xml
#     Found 19 recent papers in NEP-CBA.
#   - Processing NEP-AIN from https://nep.repec.org/rss/nep-ain.rss.xml
#     Found 12 recent papers in NEP-AIN.
#   - Processing NEP-IFN from https://nep.repec.org/rss/nep-ifn.rss.xml
#     Found 4 recent papers in NEP-IFN.
#   - Processing NEP-FMK from https://nep.repec.org/rss/nep-fmk.rss.xml
#     Found 5 recent papers in NEP-FMK.
#   - Processing NEP-RMG from https://nep.repec.org/rss/nep-rmg.rss.xml
#     Found 7 recent papers in NEP-RMG.
#   - Processing NEP-PPM from https://nep.repec.org/rss/nep-ppm.rss.xml
#     Found 4 recent papers in NEP-PPM.
#   - Processing NEP-ENE from https://nep.repec.org/rss/nep-ene.rss.xml
#     Found 13 recent papers in NEP-ENE.
#   - Processing NEP-RES from https://nep.repec.org/rss/nep-res.rss.xml
#     Found 1 recent papers in NEP-RES.
#   - Processing arXiv-econEM from http://export.arxiv.org/rss/econ.GM
#     Found 0 recent papers in arXiv-econEM.
#   - Processing arXiv-statML from http://export.arxiv.org/rss/stat.ML
#     Found 0 recent papers in arXiv-statML.
#   - Processing arXiv-csLG from http://export.arxiv.org/rss/cs.LG
#     Found 0 recent papers in arXiv-csLG.
#   - Processing arXiv-csAI from http://export.arxiv.org/rss/cs.AI
#     Found 0 recent papers in arXiv-csAI.
#   - Processing arXiv-qFIN-ST from http://export.arxiv.org/rss/q-fin.ST
#     Found 0 recent papers in arXiv-qFIN-ST.
#   - Processing arXiv-qFIN-CP from http://export.arxiv.org/rss/q-fin.CP
#     Found 0 recent papers in arXiv-qFIN-CP.
#   - Processing arXiv-qFIN-PM from http://export.arxiv.org/rss/q-fin.PM
#     Found 0 recent papers in arXiv-qFIN-PM.
#   - Processing FEDS_Papers from https://www.federalreserve.gov/feeds/working_papers.xml
#     Found 2 recent papers in FEDS_Papers.
#   - Processing FEDS2_Papers from https://www.federalreserve.gov/feeds/feds.xml
#     Found 2 recent papers in FEDS2_Papers.
#   - Processing NYDEB_Papers from https://www.newyorkfed.org/research/rss/feeds/epr.xml
#     Found 0 recent papers in NYDEB_Papers.
#   - Processing NBER_Papers from https://www.nber.org/rss/new.xml
#     Found 0 recent papers in NBER_Papers.
#   - Processing ECB_Papers from https://www.ecb.europa.eu/rss/pub.html
#     Found 6 recent papers in ECB_Papers.
#   - Processing IMF_Papers from https://www.imf.org/en/Publications/RSS?language=eng&series=IMF%20Working%20Papers
#     Found 0 recent papers in IMF_Papers.
#   - Processing BIS_Papers from https://www.bis.org/doclist/bis_fsi_publs.rss
#     Found 0 recent papers in BIS_Papers.
#   - Processing CEPR_Papers from https://cepr.org/rss/discussion-paper
#     Found 20 recent papers in CEPR_Papers.
#   - Processing VoxEU_Papers from https://voxeu.org/rss.xml
#     Warning: Malformed feed for VoxEU_Papers. Error: <unknown>:2:751: not well-formed (invalid token)
#     Found 0 recent papers in VoxEU_Papers.
#   - Processing BOE_Papers from https://www.bankofengland.co.uk/rss/publications
#     Warning: Malformed feed for BOE_Papers. Error: <unknown>:10:2: mismatched tag
#     Found 0 recent papers in BOE_Papers.
# Found 153 total recent papers.
# Removed 2 link-based duplicates. Processing 151 unique papers.
# Processing paper 1/151: 'Temporal Fusion Transformer for Multi-Horizon Probabilistic Forecastin...'
#   -> Shortlisted! (Relevant) Score: 9.0/10
# Processing paper 2/151: 'Prompting for Policy: Forecasting Macroeconomic Scenarios with Synthet...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 3/151: 'Modeling Hawkish-Dovish Latent Beliefs in Multi-Agent Debate-Based LLM...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 4/151: 'Technical Analysis Meets Machine Learning: Bitcoin Evidence...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 5/151: 'Diffusion Index Forecast with Tensor Data...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 6/151: 'Large Bayesian Tensor Autoregressions...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 7/151: 'Robust Cauchy-Based Methods for Predictive Regressions...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 8/151: 'Causal Regime Detection in Energy Markets With Augmented Time Series S...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 9/151: 'Multifractality and sample size influence on Bitcoin volatility patter...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 10/151: 'Why Applied Macroeconomists Should Not Use Bayesian Estimation of DSGE...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 11/151: 'Multi-period Learning for Financial Time Series Forecasting...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 12/151: 'On a Stationarity Theory for Stochastic Volterra Integral Equations...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 13/151: 'Confidence Sets for the Emergence, Collapse, and Recovery Dates of a B...'
#   -> Skipped. Score below threshold: 6.0/10
# Processing paper 14/151: 'FCOC: A Fractal-Chaotic Co-driven Framework for Financial Volatility F...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 15/151: 'The moment is here: a generalised class of estimators for fuzzy regres...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 16/151: 'Are VAR models evidence for a profit-led Goodwin pattern?...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 17/151: 'Bayesian Semiparametric Causal Inference: Targeted Doubly Robust Estim...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 18/151: 'Technical Analysis Meets Machine Learning: Bitcoin Evidence...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 19/151: 'Europe in the Headlines: What Two Decades of French News Reveal about ...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 20/151: 'Monetary Policy Shocks: A New Hope. Large Language Models and Central ...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 21/151: 'Prompting for Policy: Forecasting Macroeconomic Scenarios with Synthet...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 22/151: 'JaxMARL-HFT: GPU-Accelerated Large-Scale Multi-Agent Reinforcement Lea...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 23/151: 'Technical Analysis Meets Machine Learning: Bitcoin Evidence...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 24/151: 'One model to solve them all: 2BSDE families via neural operators...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 25/151: 'Prompting for Policy: Forecasting Macroeconomic Scenarios with Synthet...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 26/151: 'ABIDES-MARL: A Multi-Agent Reinforcement Learning Environment for Endo...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 27/151: 'Modeling Hawkish-Dovish Latent Beliefs in Multi-Agent Debate-Based LLM...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 28/151: 'Novelty and Impact of Economics Papers...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 29/151: 'Making Interpretable Discoveries from Unstructured Data: A High-Dimens...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 30/151: 'Takatoshi Ito: Scholarship on Japan's Economy Transformed...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 31/151: 'Scalable Global Solution Techniques for High-Dimensional Models in Dyn...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 32/151: 'Passive investing and the rise of mega-firms...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 33/151: 'Immigration, Identity Choices, and Cultural Diversity...'
#   -> Skipped. Score below threshold: 1.0/10
# Processing paper 34/151: 'When to Align and When to Contract: Technology Shocks, Optimal Policie...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 35/151: 'The moment is here: a generalised class of estimators for fuzzy regres...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 36/151: 'Levy-stable scaling of risk and performance functionals...'
#   -> Skipped. Score below threshold: 6.0/10
# Processing paper 37/151: 'Local Tax Havens...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 38/151: 'Multifractality and sample size influence on Bitcoin volatility patter...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 39/151: 'Sovereign AI: Rethinking Autonomy in the Age of Global Interdependence...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 40/151: 'Rethinking student loan design: evidence from a price-based reform in ...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 41/151: 'Digitalisation, social media and bank deposit dynamics: evidence from ...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 42/151: 'When Reasoning Fails: Evaluating 'Thinking' LLMs for Stock Prediction...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 43/151: 'Sprache(n) im Beruf: Gestaltung und Förderung beruflicher Sprachbildun...'
#   -> Skipped. Score below threshold: 1.0/10
# Processing paper 44/151: 'Impact of wheat-legume mix intercrops on wheat epidemics by modelling...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 45/151: 'Is the occupational evolution of Chinese cities driven by industrial s...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 46/151: 'When to Align and When to Contract: Technology Shocks, Optimal Policie...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 47/151: 'Money Talks: How Foreign and Domestic Monetary Policy Communications M...'
#   -> Skipped. Score below threshold: 6.0/10
# Processing paper 48/151: 'The Granular Origins of Inflation...'
#   -> Skipped. Score below threshold: 6.0/10
# Processing paper 49/151: 'Adding Macroprudential Policy to the Mix: When Monetary, Fiscal and Ma...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 50/151: 'Nonlinear Estimation of a New Keynesian Model with Endogenous Inflatio...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 51/151: 'Sectoral Spillovers in Inflation Dynamics: Empirical Evidence from Net...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 52/151: 'Digitalisation, social media and bank deposit dynamics: evidence from ...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 53/151: 'Monetary Policy Shocks and Narrative Restrictions: Rules Matter...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 54/151: 'The fiscal sources of euro area inflation through the lens of the Bern...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 55/151: 'The Global Reach of US Monetary Policy: Suggestive Evidence from the G...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 56/151: 'Consumer preferences for a digital euro: insights from a discrete choi...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 57/151: 'FX debt and optimal exchange rate hedging...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 58/151: 'A literature review on ex-ante and ex-post analysis of the implication...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 59/151: 'Monetary policy transmission to investment: evidence from a survey on ...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 60/151: 'The Mortgage Debt Channel of Monetary Policy when Mortgages are Liquid...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 61/151: 'Investment funds and the monetary-macroprudential policy interplay...'
#   -> Skipped. Score below threshold: 6.0/10
# Processing paper 62/151: 'The Governance of Macroprudential Policy...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 63/151: 'Monetary policy transmission: a reference guide through ESCB models an...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 64/151: 'The Global Reach of US Monetary Policy: Suggestive Evidence from the G...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 65/151: 'Monetary and fiscal policy interactions in the aftermath of an inflati...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 66/151: 'Monetary Policy Shocks and Narrative Restrictions: Rules Matter...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 67/151: 'Navigating the sea of natural real interest rate estimates...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 68/151: 'The Not So Quiet Revolution: signal and noise in central bank communic...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 69/151: 'Monetary Policy, Financing Constraints, and Rational Asset Price Bubbl...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 70/151: 'The Role of Ambiguity in the Monetary Policy Transmissions: Evidence f...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 71/151: 'The Power of Words: Central Bank Green Communication and Performance o...'
#   -> Skipped. Score below threshold: 6.0/10
# Processing paper 72/151: 'Diversifying sovereign risk in the Euro area: empirical analysis of di...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 73/151: 'Collateral easing in non-standard times: a review of the role of Addit...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 74/151: 'Macroprudential policies and homeownership...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 75/151: 'A machine learning approach to real time identification of turning poi...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 76/151: 'Household borrowing and monetary policy transmission: post-pandemic in...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 77/151: 'Non-homothetic Preferences and the Demand Channel of Inflation...'
#   -> Skipped. Score below threshold: 6.0/10
# Processing paper 78/151: 'Making Talk Cheap: Generative AI and Labor Market Signaling...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 79/151: 'Misaligned by Design: Incentive Failures in Machine Learning...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 80/151: 'Algorithmic Advice as a Strategic Signal on Competitive Markets...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 81/151: 'AI Images, Labels and News Demand...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 82/151: 'Why Do Civil Servants Delegate Empathic Engagement with Clients to Art...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 83/151: 'Prudential Reliability of Large Language Models in Reinsurance: Govern...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 84/151: 'The LLM Pro Finance Suite: Multilingual Large Language Models for Fina...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 85/151: 'AI Investment and Firm Productivity: How Executive Demographics Drive ...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 86/151: 'Information Extraction from Fiscal Documents using LLMs...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 87/151: 'Measuring economic outlook in the news timely and efficiently...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 88/151: 'Reasoning on Time-Series for Financial Technical Analysis...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 89/151: 'Generative Agents and Expectations: Do LLMs Align with Heterogeneous A...'
#   -> Skipped. Score below threshold: 6.0/10
# Processing paper 90/151: 'FX debt and optimal exchange rate hedging...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 91/151: 'Money Talks: How Foreign and Domestic Monetary Policy Communications M...'
#   -> Skipped. Score below threshold: 6.0/10
# Processing paper 92/151: 'Informal Institutions and Global Trade: Real Effects of the Elusive...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 93/151: 'Takatoshi Ito: Scholarship on Japan's Economy Transformed...'
#   -> Skipped. Score below threshold: 1.0/10
# Processing paper 94/151: 'Corporate Earnings Announcements and Stock Market Bubbles...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 95/151: '"It Looks All the Same to Me": Cross-index Training for Long-term Fina...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 96/151: 'Why Do Banks Have So Much Debt In Tax Havens?...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 97/151: 'Electricity Sales and Forecasting of Stock Market Realized Volatility:...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 98/151: 'TOPIX Revisions and Stock Returns: Evidence for Phased Exclusions...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 99/151: 'Contemporaneous and Lagged 𝑅2 Decomposed Connectedness: Evidence for S...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 100/151: 'Lambda Value-at-Risk under ambiguity and risk sharing...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 101/151: 'An econometric investigation on the stability of stablecoins: Are thes...'
#   -> Skipped. Score below threshold: 6.0/10
# Processing paper 102/151: 'On the estimation of leverage effect and volatility of volatility in t...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 103/151: 'Rare Disasters, Tail Aversion, and Asset Pricing Puzzles...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 104/151: 'Spectral analysis of high-dimensional spot volatility matrix with appl...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 105/151: 'Cost-of-capital valuation with risky assets...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 106/151: 'The Horizon effect: A counterfactual analysis of EU Research & Innovat...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 107/151: 'Public administrators as politicians in office...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 108/151: 'Startup acquisitions and innovation∗...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 109/151: 'Not Just Astronauts: Gender Diagnosis and Budgeting in India's Space S...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 110/151: 'Energy transition and economic growth in Colombia: A dynamic cge Model...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 111/151: 'Leverage and the Low-Carbon Transition in Europe...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 112/151: 'The Effects of Carbon taxation and Climate Financing on the Malagasy E...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 113/151: 'European electricity wholesale price convergence: Investigating Flow-B...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 114/151: 'Green versus Conventional Corporate Debt: From Issuances to Emissions...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 115/151: 'Pricing of Green Bonds: Greenium Dynamics and the Role of Retail Inves...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 116/151: 'Green Startup Report 2025...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 117/151: 'Contemporaneous and Lagged 𝑅2 Decomposed Connectedness: Evidence for S...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 118/151: 'Spillover Effects between Financial and Physical Copper Markets...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 119/151: 'How Real Is Climate Change? Public Perception in Central Asia, Caucasu...'
#   -> Skipped. Score below threshold: 1.0/10
# Processing paper 120/151: 'Ecologically unequal exchange and transition-critical minerals : China...'
#   -> Skipped. Score below threshold: 1.0/10
# Processing paper 121/151: 'What the ‘Global South’ wants: necessary reforms to the international ...'
#   -> Skipped. Score below threshold: 1.0/10
# Processing paper 122/151: 'Natural-gas storage modelling by deep reinforcement learning...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 123/151: 'Cisterns for Life: Climate Adaptation Policies for Water Provision and...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 124/151: 'FEDS Paper: Cyber Vulnerabilities at Large US Financial Institutions a...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 125/151: 'FEDS Paper: Access to Capital and the IPO Decision: An Analysis of US ...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 126/151: 'Monetary transmission with frequent policy events...'
#   -> Skipped. Score below threshold: 6.0/10
# Processing paper 127/151: 'Dataset EA EMPD...'
#   -> Skipped. Score below threshold: 1.0/10
# Processing paper 128/151: 'What safe haven after the April US tariff announcement? Implications f...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 129/151: 'Financial Stability Review, November 2025...'
#   -> Skipped. Score below threshold: 1.0/10
# Processing paper 130/151: 'Inflation risk and heterogeneous trading down...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 131/151: 'Systemic risks in linkages between banks and the non-bank financial se...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 132/151: 'DP20873 Electoral Systems and Immigration Policies...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 133/151: 'DP20871 Taxing and nudging to reduce carbon emissions: Results from an...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 134/151: 'DP20872 Navigating Motherhood: Endogenous Penalties and Career Choice...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 135/151: 'DP20869 Gender and Religion: A Survey...'
#   -> Skipped. Score below threshold: 1.0/10
# Processing paper 136/151: 'DP20868 Optimally Informative Rankings and Consumer Search...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 137/151: 'DP20870 Accommodating Emerging Giants in the Global Economy...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 138/151: 'DP20866 Unraveling the Drivers of Energy-saving Technical Change...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 139/151: 'DP20867 Oligopolistic Information Markets...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 140/151: 'DP20864 Liquidity Crises in Opaque Markets: The NYSE in the Panic of 1...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 141/151: 'DP20863 Should we stop the COPs ?...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 142/151: 'DP20865 Estimating the Impact of Loan Supply Shocks...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 143/151: 'DP20862 GCAP Public Security-Level Data on U.S. Fund Holdings...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 144/151: 'DP20861 Impact Through Catalytic Finance...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 145/151: 'DP20859 Internal vs. External Shocks in Weakening Democracies: Evidenc...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 146/151: 'DP20860 Division of Labor in the Global Economy...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 147/151: 'DP20858 Top Income Concentration in Early Modern Spain, 1574-1799...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 148/151: 'DP20854 Refugees and Entrepreneurship: Evidence from Ukrainians in Pol...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 149/151: 'DP20856 How to Determine Key Players when Spillovers are Large...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 150/151: 'DP20857 Emerging Market Resilience: Good Luck or Good Policies?...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 151/151: 'DP20855 The Economic Value of Nations (for Others)...'
#   -> Skipped. Score below threshold: 2.0/10
# ✅ Internal review file saved: newsletters/2025-11-30_ets4_monthly_INTERNAL.md
# ✅ Public newsletter file saved: newsletters/2025-11-30_ets4_monthly_PUBLIC.md
#
# --- Pipeline Finished ---
# Total unique papers processed by LLM: 151
# Shortlisted 18 'Directly Relevant' papers.
# Shortlisted 0 'Papers of Interest'.
