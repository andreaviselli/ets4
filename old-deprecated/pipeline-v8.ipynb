# %%
import feedparser
from openai import OpenAI
import datetime
from dateutil import parser as dateparser
import json
import requests
import os
import re # Import regex for creating anchor slugs
from bs4 import BeautifulSoup # For cleaning HTML from summaries
from dotenv import load_dotenv

# ------------- CONFIG ----------------

# Load environment variables from .env file (must be in the same directory)
load_dotenv()
   
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
  
if not OPENAI_API_KEY:
	raise ValueError("OPENAI_API_KEY not found. Make sure it's set in your .env file.")

# Use the modern OpenAI client
client = OpenAI(api_key=OPENAI_API_KEY)

# Using gpt-4o-mini: faster, more capable, and cost-effective for this task.
LLM_MODEL = "gpt-4o-mini"

# --- User-Curated RSS Feeds ---
RSS_FEEDS = {
    # NEP - Economics
    "NEP-FOR": "https://nep.repec.org/rss/nep-for.rss.xml",   # **Forecasting** (Most Important)
    "NEP-ETS": "https://nep.repec.org/rss/nep-ets.rss.xml",   # Econometric Time Series
    "NEP-BIG": "https://nep.repec.org/rss/nep-big.rss.xml",   # Big Data
    "NEP-CMP": "https://nep.repec.org/rss/nep-cmp.rss.xml",   # Computational Economics
    "NEP-MAC": "https://nep.repec.org/rss/nep-mac.rss.xml",   # Macroeconomics
    "NEP-MON": "https://nep.repec.org/rss/nep-mon.rss.xml",   # Monetary Economics
    "NEP-MFD": "https://nep.repec.org/rss/nep-mfd.rss.xml",   # Macrofinance
    "NEP-CBA": "https://nep.repec.org/rss/nep-cba.rss.xml",   # Central Banking
    "NEP-AIN": "https://nep.repec.org/rss/nep-ain.rss.xml",   # Artificial Intelligence
    "NEP-IFN": "https://nep.repec.org/rss/nep-ifn.rss.xml",   # International Finance
    
    # NEP - Finance
    "NEP-FMK": "https://nep.repec.org/rss/nep-fmk.rss.xml",   # Financial Markets
    "NEP-RMG": "https://nep.repec.org/rss/nep-rmg.rss.xml",   # Risk Management
    "NEP-PPM": "https://nep.repec.org/rss/nep-ppm.rss.xml",   # Project, Program and Portfolio Management

    # NEP - Energy & Resource Focused
    "NEP-ENE": "https://nep.repec.org/rss/nep-ene.rss.xml",   # Energy Economics
    "NEP-RES": "https://nep.repec.org/rss/nep-res.rss.xml",   # Resource Economics

    # ArXiv - Core Quantitative & CS Fields
    "arXiv-econEM": "http://export.arxiv.org/rss/econ.EM",     # Econometrics
    "arXiv-statML": "http://export.arxiv.org/rss/stat.ML",     # Statistics - Machine Learning
    "arXiv-csLG": "http://export.arxiv.org/rss/cs.LG",         # Computer Science - Machine Learning
    "arXiv-qFIN-ST": "http://export.arxiv.org/rss/q-fin.ST",   # Quantitative Finance - Statistical Methods
    "arXiv-qFIN-CP": "http://export.arxiv.org/rss/q-fin.CP",   # Quantitative Finance - Computational Finance

    # High-Signal Institutions (Central Banks & Academic Orgs)
    "FEDS_Papers": "https://www.federalreserve.gov/feeds/working_papers.xml",     # US Federal Reserve Board
    "ECB_Papers": "https://www.ecb.europa.eu/rss/pub.html",                       # European Central Bank
    "IMF_Papers": "https://www.imf.org/en/Publications/RSS?language=eng&series=IMF%20Working%20Papers", # International Monetary Fund
    "BIS_Papers": "https://www.bis.org/doclist/bis_fsi_publs.rss",                # Bank for International Settlements
    "CEPR_Papers": "https://cepr.org/rss/discussion-paper",                       # Centre for Economic Policy Research (CEPR)
}


SCORE_THRESHOLD = 8.0  # Keep only papers scoring above this
DAYS_BACK = 30         # Look back this many days
OUTPUT_DIR = "newsletters"

# ------------- HELPER FUNCTIONS ----------------

def _get_authors(entry):
    """Normalizes author information from a feed entry."""
    if hasattr(entry, 'authors') and entry.authors:
        return ', '.join(author['name'] for author in entry.authors if 'name' in author)
    if hasattr(entry, 'author'):
        return entry.author
    return "Unknown"

def _create_anchor_slug(title, index):
    """Creates a URL-friendly slug from a title for anchor links."""
    s = title.lower()
    s = re.sub(r'[^\w\s-]', '', s) # Remove non-alphanumeric characters
    s = re.sub(r'[\s_-]+', '-', s).strip('-') # Replace spaces with hyphens
    return f"{s}-{index}"

# ------------- CORE FUNCTIONS ----------------

def fetch_recent_papers():
    """Fetch recent papers from RSS feeds with robust date parsing and encoding correction."""
    print(f"Fetching papers from {len(RSS_FEEDS)} sources, looking back {DAYS_BACK} days...")
    cutoff_date = datetime.datetime.now(datetime.timezone.utc) - datetime.timedelta(days=DAYS_BACK)
    papers = []

    for source, url in RSS_FEEDS.items():
        print(f"  - Processing {source} from {url}")
        try:
            response = requests.get(url, timeout=15)
            if "utf-8" in response.text.lower() or "<?xml" in response.text:
                response.encoding = "utf-8"
            feed = feedparser.parse(response.text)
            if feed.bozo:
                print(f"    Warning: Malformed feed for {source}. Error: {feed.bozo_exception}")

            found_in_feed = 0
            for entry in feed.entries:
                pub_date_str = getattr(entry, "published", getattr(entry, "updated", None))
                if not pub_date_str: continue
                try:
                    pub_date = dateparser.parse(pub_date_str)
                except dateparser.ParserError:
                    continue
                if pub_date.tzinfo is None:
                    pub_date = pub_date.replace(tzinfo=datetime.timezone.utc)
                if pub_date < cutoff_date: continue
                summary = getattr(entry, "summary", "")
                if "<" in summary and ">" in summary:
                    summary = BeautifulSoup(summary, "html.parser").get_text(separator=' ', strip=True)
                papers.append({
                    "title": entry.title, "link": entry.link, "summary": summary,
                    "authors": _get_authors(entry), "source": source, "date": pub_date.strftime("%Y-%m-%d")
                })
                found_in_feed += 1
            print(f"    Found {found_in_feed} recent papers in {source}.")
        except Exception as e:
            print(f"    Error fetching or parsing feed {source}: {e}")
            continue
    return papers

def score_and_summarize(paper):
    """Sends abstract to LLM for summary, scoring, and categorization."""
    prompt = f"""
You are a highly specialized expert curator for "ets4 Monthly (Economic Time Series Forecasting Monthly)," a newsletter focused **exclusively on practical and impactful forecasting of economic time series.** Your role is to identify only the most relevant and innovative work for an audience of researchers and practitioners.

You will be given a research paper. Evaluate it strictly through the lens of **forecasting relevance and potential to advance economic prediction.** Papers that focus on **structural analysis, causal inference, descriptive statistics, or purely theoretical econometrics without a predictive component must be classified as Not Relevant**, even if they appear in economics journals.

---

**Paper Information**

Title: {paper['title']}
Authors: {paper['authors']}
Source: {paper['source']}
Date: {paper['date']}
Abstract: {paper['summary']}

---

### Your Tasks

1. **Summarize (3-4 sentences)**  
   Focus only on elements related to **forecasting or predictive modeling**. If forecasting is not clearly present, explicitly say so.

2. **Assign a Quality Score (1–10)**  
   Score based on **forecasting methodological novelty, empirical rigor, and potential practical impact.**  
   - **Extra weight should be given** to papers that:
     - Introduce **new modeling approaches** or **improve existing ones significantly**.
     - Use **novel datasets** that could meaningfully enhance economic forecasting.
     - Present **forecasting applications with real-world decision value** (e.g. monetary policy, energy prices, financial trading, inflation nowcasting).

3. **Classify into One Category**  
   Choose exactly one:
   - **Directly Relevant** → The paper is clearly about **forecasting *economic* time series** and offers meaningful contributions or applications.
   - **Paper of Interest** → The paper is *not economic*, but presents **highly innovative forecasting methods or data strategies** that could plausibly transfer to economics.
   - **Not Relevant** → No clear predictive component, or relevance is too indirect (e.g., **structural models, policy simulations without forecasting, causal effects estimation, variance decompositions, statistical/econometric theory without prediction focus**).

---

### Scoring & Categorization Rules

| Score | Meaning | Default Category |
|--------|---------|------------------|
| **1–3** | Low quality OR no forecasting at all | Not Relevant |
| **4–6** | Minor/incremental forecasting contribution OR niche application with little general value | Not Relevant |
| **7–8** | Solid contribution to forecasting | Directly Relevant *if economic*, otherwise Paper of Interest |
| **9–10** | Breakthrough forecasting methodology, dataset, or application with clear future impact | Directly Relevant *if economic*, otherwise Paper of Interest |

---

### JSON Output Format

Return your response strictly in **valid JSON** using the following schema:

{{
"summary": "...",
"score": X,
"category": "Directly Relevant" | "Paper of Interest" | "Not Relevant",
"adaptability_reason": null | "Required only if category is 'Paper of Interest'"
}}

- If you select **Paper of Interest**, you **must** fill in `"adaptability_reason"` with a short statement explaining how the method could be applied to economic forecasting.
- For **Directly Relevant** or **Not Relevant**, set `"adaptability_reason": null`.
"""
    try:
        response = client.chat.completions.create(
            model=LLM_MODEL,
            messages=[{"role": "user", "content": prompt}],
            temperature=0.2,
            response_format={"type": "json_object"}
        )
        content = response.choices[0].message.content
        data = json.loads(content)
        required_keys = ["summary", "score", "category", "adaptability_reason"]
        if not all(key in data for key in required_keys):
            raise ValueError(f"LLM response missing one or more required keys: {required_keys}")
        if not isinstance(data["score"], (int, float)):
            raise ValueError("LLM score is not a number.")
        if data["category"] == "Paper of Interest" and not data.get("adaptability_reason"):
            raise ValueError("Category is 'Paper of Interest' but adaptability_reason is missing.")
        data["score"] = float(data["score"])
        return data
    except Exception as e:
        print(f"Error during LLM call for paper '{paper['title']}': {e}")
        return {"summary": f"Error: {e}", "score": 0.0, "category": "Not Relevant", "adaptability_reason": None}

def build_internal_markdown(relevant_papers, interest_papers, filename):
    """Creates the internal markdown file WITH scores for review."""
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    today_str = datetime.date.today().strftime('%Y-%m-%d')
    lines = [f"# ets4 Monthly [INTERNAL] – {today_str}\n", "Internal review copy with quality scores.\n"]
    lines.append("## Directly Relevant Papers\n")
    if not relevant_papers:
        lines.append("No directly relevant papers met the criteria this month.\n")
    else:
        relevant_papers.sort(key=lambda p: p['score'], reverse=True)
        for p in relevant_papers:
            lines.append(f"### [{p['title']}]({p['link']})")
            lines.append(f"- **Authors:** {p['authors']}")
            lines.append(f"- **Source:** {p['source']} ({p['date']})")
            lines.append(f"- **Quality Score:** {p['score']:.1f}/10")
            lines.append(f"- **Summary:** {p['summary']}\n")
    lines.append("\n---\n")
    lines.append("## Papers of Interest\n")
    if not interest_papers:
        lines.append("No papers of interest were identified this month.\n")
    else:
        interest_papers.sort(key=lambda p: p['score'], reverse=True)
        for p in interest_papers:
            lines.append(f"### [{p['title']}]({p['link']})")
            lines.append(f"- **Authors:** {p['authors']}")
            lines.append(f"- **Source:** {p['source']} ({p['date']})")
            lines.append(f"- **Quality Score:** {p['score']:.1f}/10")
            lines.append(f"- **Summary:** {p['summary']}")
            lines.append(f"- **Reason for Interest:** {p.get('adaptability_reason', 'N/A')}\n")
    with open(filename, "w", encoding="utf-8") as f:
        f.write("\n".join(lines))
    print(f"✅ Internal review file saved: {filename}")

def build_public_markdown(relevant_papers, interest_papers, filename):
    """Creates a public-facing markdown file with a correctly numbered Table of Contents, anchor links, and no scores."""
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    today = datetime.date.today()
    
    iso_date_str = today.strftime('%Y-%m-%d')
    title_date_str = today.strftime('%B %d, %Y')

    front_matter = f"""---
title: "ets4 Newsletter, {title_date_str}"
date: {iso_date_str}
draft: true
---
"""
    lines = [
        front_matter,
        f"# ets4 Monthly – {iso_date_str}\n",
        "A curated list of recent papers on novel methods for forecasting economic time series.\n"
    ]

    # --- Deduplicate and Sort Papers ---
    seen_titles = set()
    unique_relevant = []
    for p in sorted(relevant_papers, key=lambda x: x['score'], reverse=True):
        normalized_title = p['title'].lower().strip()
        if normalized_title not in seen_titles:
            unique_relevant.append(p)
            seen_titles.add(normalized_title)

    unique_interest = []
    for p in sorted(interest_papers, key=lambda x: x['score'], reverse=True):
        normalized_title = p['title'].lower().strip()
        if normalized_title not in seen_titles:
            unique_interest.append(p)
            seen_titles.add(normalized_title)

    # --- Build Table of Contents ---
    if unique_relevant:
        lines.append("## Directly Relevant Papers\n")
        lines.append("### In this Issue\n")
        for i, p in enumerate(unique_relevant):
            anchor = _create_anchor_slug(p['title'], i)
            # --- FIX: Use the loop index (i + 1) instead of a hardcoded "1." ---
            lines.append(f"{i + 1}. [{p['title']} - *{p['authors']}*](#{anchor})")
        lines.append("")

    if unique_interest:
        if not unique_relevant:
             lines.append("## Papers of Interest\n")
        else:
            lines.append("\n---\n")
            lines.append("## Papers of Interest\n")
        lines.append("_Methodologically novel papers from other fields that could be adapted for economic forecasting._\n")
        lines.append("### In this Issue\n")
        for i, p in enumerate(unique_interest):
            anchor = _create_anchor_slug(p['title'], len(unique_relevant) + i)
            # --- FIX: Use the loop index (i + 1) instead of a hardcoded "1." ---
            lines.append(f"{i + 1}. [{p['title']} - *{p['authors']}*](#{anchor})")
        lines.append("")

    # --- Build Full Paper Details ---
    if unique_relevant:
        lines.append("\n---\n")
        lines.append("### Paper Details\n")
        for i, p in enumerate(unique_relevant):
            anchor = _create_anchor_slug(p['title'], i)
            lines.append(f"### [{p['title']}]({p['link']}) {{#{anchor}}}")
            lines.append(f"- **Authors:** {p['authors']}")
            lines.append(f"- **Source:** {p['source']} ({p['date']})")
            lines.append(f"- **Summary:** {p['summary']}\n")
    
    if unique_interest:
        # Add a separator only if there were relevant papers before this section
        if unique_relevant:
            lines.append("\n---\n")
        lines.append("### Paper Details\n")
        for i, p in enumerate(unique_interest):
            anchor = _create_anchor_slug(p['title'], len(unique_relevant) + i)
            lines.append(f"### [{p['title']}]({p['link']}) {{#{anchor}}}")
            lines.append(f"- **Authors:** {p['authors']}")
            lines.append(f"- **Source:** {p['source']} ({p['date']})")
            lines.append(f"- **Summary:** {p['summary']}")
            lines.append(f"- **Reason for Interest:** {p.get('adaptability_reason', 'N/A')}\n")

    if not unique_relevant and not unique_interest:
        lines.append("## No papers met the criteria this month. Check back soon!\n")
        
    with open(filename, "w", encoding="utf-8") as f:
        f.write("\n".join(lines))
    print(f"✅ Public newsletter file saved: {filename}")


# ------------- MAIN ----------------

if __name__ == "__main__":
    print("Starting Economic Forecasting Newsletter Pipeline...")
    all_papers = fetch_recent_papers()
    print(f"Found {len(all_papers)} total recent papers.")
    unique_papers = []
    seen_links = set()
    for paper in all_papers:
        if paper['link'] not in seen_links:
            unique_papers.append(paper)
            seen_links.add(paper['link'])
    if len(all_papers) > len(unique_papers):
        print(f"Removed {len(all_papers) - len(unique_papers)} link-based duplicates. Processing {len(unique_papers)} unique papers.")
    
    shortlisted_relevant = []
    shortlisted_interest = []
    for i, paper in enumerate(unique_papers, 1):
        print(f"Processing paper {i}/{len(unique_papers)}: '{paper['title'][:70]}...'")
        result = score_and_summarize(paper)
        paper.update(result)
        if paper.get("score", 0.0) >= SCORE_THRESHOLD:
            if paper.get("category") == "Directly Relevant":
                shortlisted_relevant.append(paper)
                print(f"  -> Shortlisted! (Relevant) Score: {paper['score']:.1f}/10")
            elif paper.get("category") == "Paper of Interest":
                shortlisted_interest.append(paper)
                print(f"  -> Shortlisted! (Interest) Score: {paper['score']:.1f}/10")
            else:
                print(f"  -> Skipped. Category: {paper.get('category', 'Unknown')}, Score: {paper['score']:.1f}/10")
        else:
            print(f"  -> Skipped. Score below threshold: {paper.get('score', 0.0):.1f}/10")
    
    today_str = datetime.date.today().strftime("%Y-%m-%d")
    internal_filename = os.path.join(OUTPUT_DIR, f"ets4_monthly_{today_str}_INTERNAL.md")
    public_filename = os.path.join(OUTPUT_DIR, f"ets4_monthly_{today_str}_PUBLIC.md")
    
    build_internal_markdown(shortlisted_relevant, shortlisted_interest, internal_filename)
    build_public_markdown(shortlisted_relevant, shortlisted_interest, public_filename)
    
    print("\n--- Pipeline Finished ---")
    print(f"Total unique papers processed by LLM: {len(unique_papers)}")
    print(f"Shortlisted {len(shortlisted_relevant)} 'Directly Relevant' papers.")
    print(f"Shortlisted {len(shortlisted_interest)} 'Papers of Interest'.")
# Out:
# Starting Economic Forecasting Newsletter Pipeline...
# Fetching papers from 25 sources, looking back 30 days...
#   - Processing NEP-FOR from https://nep.repec.org/rss/nep-for.rss.xml
#     Found 1 recent papers in NEP-FOR.
#   - Processing NEP-ETS from https://nep.repec.org/rss/nep-ets.rss.xml
#     Found 8 recent papers in NEP-ETS.
#   - Processing NEP-BIG from https://nep.repec.org/rss/nep-big.rss.xml
#     Found 3 recent papers in NEP-BIG.
#   - Processing NEP-CMP from https://nep.repec.org/rss/nep-cmp.rss.xml
#     Found 13 recent papers in NEP-CMP.
#   - Processing NEP-MAC from https://nep.repec.org/rss/nep-mac.rss.xml
#     Found 24 recent papers in NEP-MAC.
#   - Processing NEP-MON from https://nep.repec.org/rss/nep-mon.rss.xml
#     Found 34 recent papers in NEP-MON.
#   - Processing NEP-MFD from https://nep.repec.org/rss/nep-mfd.rss.xml
#     Found 1 recent papers in NEP-MFD.
#   - Processing NEP-CBA from https://nep.repec.org/rss/nep-cba.rss.xml
#     Found 4 recent papers in NEP-CBA.
#   - Processing NEP-AIN from https://nep.repec.org/rss/nep-ain.rss.xml
#     Found 9 recent papers in NEP-AIN.
#   - Processing NEP-IFN from https://nep.repec.org/rss/nep-ifn.rss.xml
#     Found 4 recent papers in NEP-IFN.
#   - Processing NEP-FMK from https://nep.repec.org/rss/nep-fmk.rss.xml
#     Found 3 recent papers in NEP-FMK.
#   - Processing NEP-RMG from https://nep.repec.org/rss/nep-rmg.rss.xml
#     Found 5 recent papers in NEP-RMG.
#   - Processing NEP-PPM from https://nep.repec.org/rss/nep-ppm.rss.xml
#     Found 3 recent papers in NEP-PPM.
#   - Processing NEP-ENE from https://nep.repec.org/rss/nep-ene.rss.xml
#     Found 19 recent papers in NEP-ENE.
#   - Processing NEP-RES from https://nep.repec.org/rss/nep-res.rss.xml
#     Found 1 recent papers in NEP-RES.
#   - Processing arXiv-econEM from http://export.arxiv.org/rss/econ.EM
#     Found 9 recent papers in arXiv-econEM.
#   - Processing arXiv-statML from http://export.arxiv.org/rss/stat.ML
#     Found 45 recent papers in arXiv-statML.
#   - Processing arXiv-csLG from http://export.arxiv.org/rss/cs.LG
#     Found 328 recent papers in arXiv-csLG.
#   - Processing arXiv-qFIN-ST from http://export.arxiv.org/rss/q-fin.ST
#     Found 2 recent papers in arXiv-qFIN-ST.
#   - Processing arXiv-qFIN-CP from http://export.arxiv.org/rss/q-fin.CP
#     Found 2 recent papers in arXiv-qFIN-CP.
#   - Processing FEDS_Papers from https://www.federalreserve.gov/feeds/working_papers.xml
#     Found 15 recent papers in FEDS_Papers.
#   - Processing ECB_Papers from https://www.ecb.europa.eu/rss/pub.html
#     Found 15 recent papers in ECB_Papers.
#   - Processing IMF_Papers from https://www.imf.org/en/Publications/RSS?language=eng&series=IMF%20Working%20Papers
#     Found 10 recent papers in IMF_Papers.
#   - Processing BIS_Papers from https://www.bis.org/doclist/bis_fsi_publs.rss
#     Found 0 recent papers in BIS_Papers.
#   - Processing CEPR_Papers from https://cepr.org/rss/discussion-paper
#     Found 50 recent papers in CEPR_Papers.
# Found 608 total recent papers.
# Removed 45 link-based duplicates. Processing 563 unique papers.
# Processing paper 1/563: 'Assessing Asymmetric Macroeconomic Risk...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 2/563: 'VAR Models With An Index Structure: A Survey With New Results...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 3/563: 'Simple Tests for the Correct Specification of Conditional Predictive D...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 4/563: 'Quantile Granger Causality in the Presence of Instability...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 5/563: 'Matrix-valued factor model with time-varying main effects...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 6/563: 'Optimal Estimation In A Multicointegrated System...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 7/563: 'Persistence in Stock Returns: Robotics and AI ETFs Versus Other Assets...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 8/563: 'Virtue or Mirage? Complexity in Exchange Rate Prediction...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 9/563: 'A Realtime Analysis of Fundamentals and Bubbles in the S&P 500...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 10/563: 'Identifying economic narratives in large text corpora: An integrated a...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 11/563: 'Beyond GARCH: Bayesian Neural Stochastic Volatility...'
#   -> Shortlisted! (Relevant) Score: 9.0/10
# Processing paper 12/563: 'Random Forests for Labor Market Analysis: Balancing Precision and Inte...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 13/563: 'An Entropy Regularized BSDE Approach to Bermudan Options and Games...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 14/563: 'Financial Stability Implications of Generative AI: Taming the Animal S...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 15/563: 'Incorporating Non-Unitary Income Elasticities, Choke Prices and Choke ...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 16/563: 'Beyond content: Investors' chatter, interaction and earnings announcem...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 17/563: 'Embedding ESG in Cost Accounting: A Simulation Framework for Financial...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 18/563: 'Riding Wavelets: A Method to Discover New Classes of Financial Price J...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 19/563: 'Input-Output Approach to Assess the Economic Effects of Final Demand f...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 20/563: 'Optimal placement of wind farms via quantile constraint learning...'
#   -> Skipped. Score below threshold: 6.0/10
# Processing paper 21/563: 'Interest Rate Pass-through by U.S. Banks: Macro Implications of Bank C...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 22/563: 'From Job Titles to ISCO Codes: Enhancing Occupational Classification W...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 23/563: 'The look of success: AI-measured face factors and venture financing...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 24/563: 'Residential Location Models: Analyzing Segregation, Borrowing Constrai...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 25/563: 'Financial Structure and Mergers...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 26/563: 'The Role of Macroprudential Policy in Times of Trouble...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 27/563: 'The Emotions of Monetary Policy...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 28/563: 'When is Liquidity Bad?...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 29/563: 'Shopping Time and Frictional Goods Markets: Implications for the New-K...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 30/563: 'Imperfect Information and Slow Recoveries in the Labor Market...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 31/563: 'The Chicago Plan Revisited - Debt-free Money, Growth, and Stability...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 32/563: 'Stock-Oil Comovement: Cash Flows or Discount Rates?...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 33/563: 'How does Kant think? An interpretive proposal from an ordonomic perspe...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 34/563: 'Multinational Firms and the Urban-Rural Productivity Gap...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 35/563: 'Clean Hydrogen Pathways: Expert Projections from Australia and Implica...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 36/563: 'Unequal Lifespans and Redistribution...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 37/563: 'Lange und fragmentierte Arbeitstage: Verbreitung, Gründe und Auswirkun...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 38/563: 'Public Childcare, Labor Market Outcomes of Caregivers, and Child Devel...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 39/563: 'Congestion management games in electricity markets...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 40/563: 'The Emergence of Tokenized Investment Funds and Their Use Cases...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 41/563: 'Common Ancestry, Uncommon Findings: Revisiting Cross-Cultural Research...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 42/563: 'Representation of Women in Governing Bodies: An Analisis of Financial ...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 43/563: 'Living Wage Update Report: Northwest Nicaragua, 2025...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 44/563: 'Matrix-valued factor model with time-varying main effects...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 45/563: 'Shaping Future Success: Evidence from an Early Childhood Human Capital...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 46/563: 'Do endorsers contribute to the social standing of brands? Exploring so...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 47/563: 'Financial Structure and Mergers...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 48/563: 'Inflation's Shared DNA: Regional and Global Factors in Post-Pandemic C...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 49/563: 'Labour market power, firm productivity, and the immigrant-native pay g...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 50/563: 'Central Bank Digital Currency as a New Means of Payment: An Experiment...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 51/563: 'Drawbacks of Household Panel Data on Inflation Perceptions and Expecta...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 52/563: 'The Emotions of Monetary Policy...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 53/563: 'Subsistence consumption and inflation heterogeneity: Implications for ...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 54/563: 'Inflation Perceptions and Monetary Policy...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 55/563: 'Carbon Pricing and Monetary Policy in an Estimated Macro-Climate Model...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 56/563: 'The Curse of Flexibility Under Uncertainty...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 57/563: 'Durability, essentiality, and the transmission of monetary policy to h...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 58/563: 'Attention-Dependent Monetary Transmission to Household Beliefs...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 59/563: 'What can we learn from the distributions of inflation expectations acr...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 60/563: 'Financial conditions indices in Latin America...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 61/563: 'Inflation Expectation Disagreement and Monetary Policy Transmission in...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 62/563: 'The role of city structure in monetary policy transmission...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 63/563: 'Macroprudential policy, monetary policy and non-bank financial interme...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 64/563: 'The Impact of Interest: Firms' Investment Sensitivity to Interest Rate...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 65/563: 'Who Absorbs the Debt-Deflation Channel? Empirical Evidence from Histor...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 66/563: 'Financial Intermediaries and Pressures on International Capital Flows...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 67/563: 'What Does It Take? Quantifying Cross-Country Transfers in the Eurozone...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 68/563: 'How do rising temperatures affect inflation expectations?...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 69/563: 'Privilege Lost? The Rise and Fall of a Dominant Global Currency...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 70/563: 'Why Do Supply Disruptions Lead to Inflation?...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 71/563: 'Non-homothetic Demand Shifts and Inflation Inequality...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 72/563: 'One Policy Rate, Many Stances: Evidence from the European Monetary Uni...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 73/563: 'The Fed Funds Market During the Quantitative Tightening of 2017-19...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 74/563: 'When is Liquidity Bad?...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 75/563: 'A minimal model of money creation within secured interbank markets...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 76/563: 'Monetary Policy and Bank Funding Costs: Patterns and Predictability in...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 77/563: 'Stablecoins and the Future of Money: Economic Principles and Policy Im...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 78/563: 'Core Inflation in the Advanced Economies: A Regional Perspective...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 79/563: 'The Role of Macroprudential Policy in Times of Trouble...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 80/563: 'Personal Inflation Rates in the Euro Area...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 81/563: 'The Chicago Plan Revisited - Debt-free Money, Growth, and Stability...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 82/563: 'Inflation's Shared DNA: Regional and Global Factors in Post-Pandemic C...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 83/563: 'Hidden weaknesses: the role of unrealized losses in monetary policy tr...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 84/563: 'Testing Evolutionary Theories of Human Cooperation via Meta-Analysis o...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 85/563: 'The Signaling Effects of Tightening and Easing Monetary Policy...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 86/563: 'On the Distributional Effects of Conventional Monetary Policy and Forw...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 87/563: 'The EU’s New Expenditure Rule and Its Implications for Monetary Policy...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 88/563: 'Beyond interbank: Identifying critical participants in integrated RTGS...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 89/563: 'The Spoils of Algorithmic Collusion: Profit Allocation Among Asymmetri...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 90/563: 'Delegate Pricing Decisions to an Algorithm? Experimental Evidence...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 91/563: 'Using AI Persuasion to Reduce Political Polarization...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 92/563: 'Data, Power and Emissions: The Environmental Cost of AI...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 93/563: 'Tilting the Race Between Humans and AI: The Role of Education and Unem...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 94/563: 'Ethical Integration in Public Sector AI. The Case of Algorithmic Syste...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 95/563: 'Can artificial intelligence help improve the financial literacy of pri...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 96/563: 'Financial Stability Implications of Generative AI: Taming the Animal S...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 97/563: 'From Job Titles to ISCO Codes: Enhancing Occupational Classification W...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 98/563: 'Financial Intermediaries and Pressures on International Capital Flows...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 99/563: 'Financial conditions indices in Latin America...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 100/563: 'When is Liquidity Bad?...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 101/563: 'Privilege Lost? The Rise and Fall of a Dominant Global Currency...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 102/563: 'Asset-price redistribution...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 103/563: 'Imperfect Banking Competition and the Propagation of Uncertainty Shock...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 104/563: 'Does Pair Trading Still Work During Extreme Events? A Comprehensive Em...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 105/563: 'Examining the Relationship Between Loan Pricing and Credit Risk...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 106/563: 'The impact of capital requirements on bank capital...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 107/563: 'International risk sharing and wealth allocation with higher order cum...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 108/563: 'Do Banks Price Flood Risk in Mortgage Origination: Evidence from a Nat...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 109/563: 'Riding Wavelets: A Method to Discover New Classes of Financial Price J...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 110/563: 'Running against Windmills: Costly Perseverance in Long- and Short-Term...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 111/563: '"LogistiQuest as a Tool for Problem-Based Learning (PBL) in Cargo Proj...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 112/563: 'Support for renewable energy: The case of wind power...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 113/563: 'Renewable Energy Supply Shocks from Wind Electricity...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 114/563: 'Derisking Electricity Prices For Decarbonisation: A novel perspective ...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 115/563: 'The Price Elasticity of Heating and Cooling Energy Demand...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 116/563: 'Is Italy on Track? A Data-Driven Forecast for Road Transport Decarboni...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 117/563: 'Verbrenner oder Elektro? Ein Vergleich der Vor- und Nachteile....'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 118/563: 'When smart charging meets smart users: How price-sensitive plug-in beh...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 119/563: 'Aportes clave del estudio del Upstream Offshore en el Mar Argentino...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 120/563: 'Systemic Climate Risk...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 121/563: 'Air Quality and Conferencesâ€™ Engagement...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 122/563: 'Bridging the Gap: Estimating Scope 3 Emissions at Companyâ€™s Level...'
#   -> Skipped. Score below threshold: 6.0/10
# Processing paper 123/563: 'Unveiling the impact of geopolitical risk, climate policy uncertainty,...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 124/563: 'The comparative political economy of the green transition: economic sp...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 125/563: 'No evidence for effectiveness of behavioral interventions to mitigate ...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 126/563: 'Bridging the Gap in Macroeconomic Analysis of the Energy Transition: C...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 127/563: 'Made in France and Reshoring in Multi-Regional Input-Output Tables...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 128/563: 'Seeds of Inflation: Geopolitical Risk and Inflation: The Role of Energ...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 129/563: 'Potencial del Upstream Offshore en el Mar Argentino...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 130/563: 'Growth, Structural Transformation and Carbon Emissions...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 131/563: 'Enhancing system resilience to climate change through artificial intel...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 132/563: 'Air Quality and Conferences Engagement...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 133/563: 'Bayesian Portfolio Optimization by Predictive Synthesis...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 134/563: 'Beyond the Oracle Property: Adaptive LASSO in Cointegrating Regression...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 135/563: 'Identification and Estimation of Dynamic Games with Unknown Informatio...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 136/563: 'Debiased Machine Learning U-statistics...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 137/563: 'Inference in clustered IV models with many and weak instruments...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 138/563: 'Bootstrap Diagnostic Tests...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 139/563: 'Automatic Order, Bandwidth Selection and Flaws of Eigen Adjustment in ...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 140/563: 'Identification in Auctions with Truncated Transaction Prices...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 141/563: 'Returns and Order Flow Imbalances: Intraday Dynamics and Macroeconomic...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 142/563: 'A General Constructive Upper Bound on Shallow Neural Nets Complexity...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 143/563: 'Online Matching via Reinforcement Learning: An Expert Policy Orchestra...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 144/563: 'Q-Learning with Fine-Grained Gap-Dependent Regret...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 145/563: 'Gaussian Equivalence for Self-Attention: Asymptotic Spectral Analysis ...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 146/563: 'Bayesian Nonparametric Dynamical Clustering of Time Series...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 147/563: 'PyCFRL: A Python library for counterfactually fair offline reinforceme...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 148/563: 'Root Cause Analysis of Outliers in Unknown Cyclic Graphs...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 149/563: 'Explaining Models under Multivariate Bernoulli Distribution via Hoeffd...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 150/563: 'Diffusion-Augmented Reinforcement Learning for Robust Portfolio Optimi...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 151/563: 'Split Conformal Classification with Unsupervised Calibration...'
#   -> Skipped. Score below threshold: 6.0/10
# Processing paper 152/563: 'A Mixed-Methods Analysis of Repression and Mobilization in Bangladesh'...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 153/563: 'Mass Conservation on Rails -- Rethinking Physics-Informed Learning of ...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 154/563: 'Making and Evaluating Calibrated Forecasts...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 155/563: 'The Effect of Label Noise on the Information Content of Neural Represe...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 156/563: 'Nearly Instance-Optimal Parameter Recovery from Many Trajectories via ...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 157/563: 'Bayesian Optimization under Uncertainty for Training a Scale Parameter...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 158/563: 'A Median Perspective on Unlabeled Data for Out-of-Distribution Detecti...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 159/563: 'Wide Neural Networks as a Baseline for the Computational No-Coincidenc...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 160/563: 'Scalable Policy-Based RL Algorithms for POMDPs...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 161/563: 'The Effect of Attention Head Count on Transformer Approximation...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 162/563: 'Non-Asymptotic Analysis of Efficiency in Conformalized Regression...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 163/563: 'jmstate, a Flexible Python Package for Multi-State Joint Modeling...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 164/563: 'DPMM-CFL: Clustered Federated Learning via Dirichlet Process Mixture M...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 165/563: 'Efficient reductions from a Gaussian source with applications to stati...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 166/563: 'GyroSwin: 5D Surrogates for Gyrokinetic Plasma Turbulence Simulations...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 167/563: 'An Empirical Analysis of the Laplace and Neural Tangent Kernels...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 168/563: 'Bit-Level Discrete Diffusion with Markov Probabilistic Models: An Impr...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 169/563: 'Is Supervised Learning Really That Different from Unsupervised?...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 170/563: 'A Copula Based Supervised Filter for Feature Selection in Diabetes Ris...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 171/563: 'Enjoying Non-linearity in Multinomial Logistic Bandits...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 172/563: 'Flow Matching for Robust Simulation-Based Inference under Model Misspe...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 173/563: 'Simulation-based inference via telescoping ratio estimation for trawl ...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 174/563: 'DPGIIL: Dirichlet Process-Deep Generative Model-Integrated Incremental...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 175/563: 'Denoising Score Matching with Random Features: Insights on Diffusion M...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 176/563: 'A Differentiable Alignment Framework for Sequence-to-Sequence Modeling...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 177/563: 'Learning where to learn: Training data distribution optimization for s...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 178/563: 'Adversarial Surrogate Risk Bounds for Binary Classification...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 179/563: 'Distributional Machine Unlearning via Selective Data Removal...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 180/563: 'Valid Inference with Imperfect Synthetic Data...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 181/563: 'A Minimalist Bayesian Framework for Stochastic Optimization...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 182/563: 'Closed-form $\ell_r$ norm scaling with data for overparameterized line...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 183/563: 'A Family of Kernelized Matrix Costs for Multiple-Output Mixture Neural...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 184/563: 'On residual network depth...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 185/563: 'Longitudinal Flow Matching for Trajectory Modeling...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 186/563: 'Slow-Fast Policy Optimization: Reposition-Before-Update for LLM Reason...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 187/563: 'RareGraph-Synth: Knowledge-Guided Diffusion Models for Generating Priv...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 188/563: 'MCCE: A Framework for Multi-LLM Collaborative Co-Evolution...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 189/563: 'RVFL-X: A Novel Randomized Network Based on Complex Transformed Real-V...'
#   -> Skipped. Score below threshold: 6.0/10
# Processing paper 190/563: 'On knot detection via picture recognition...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 191/563: 'Traj-Transformer: Diffusion Models with Transformer for GPS Trajectory...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 192/563: 'BlockGPT: Spatio-Temporal Modelling of Rainfall via Frame-Level Autore...'
#   -> Shortlisted! (Interest) Score: 8.0/10
# Processing paper 193/563: 'SDAR: A Synergistic Diffusion-AutoRegression Paradigm for Scalable Seq...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 194/563: 'Flexible Swarm Learning May Outpace Foundation Models in Essential Tas...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 195/563: 'PIKAN: Physics-Inspired Kolmogorov-Arnold Networks for Explainable UAV...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 196/563: 'Lagrangian neural ODEs: Measuring the existence of a Lagrangian with H...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 197/563: 'Relational Transformer: Toward Zero-Shot Foundation Models for Relatio...'
#   -> Shortlisted! (Interest) Score: 8.0/10
# Processing paper 198/563: 'Monte Carlo Permutation Search...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 199/563: 'Geometry-Aware Backdoor Attacks: Leveraging Curvature in Hyperbolic Em...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 200/563: 'Test-Time Efficient Pretrained Model Portfolios for Time Series Foreca...'
#   -> Shortlisted! (Interest) Score: 8.0/10
# Processing paper 201/563: 'Context-Aware Inference via Performance Forecasting in Decentralized L...'
#   -> Shortlisted! (Interest) Score: 8.0/10
# Processing paper 202/563: 'How NOT to benchmark your SITE metric: Beyond Static Leaderboards and ...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 203/563: 'Attention Sinks and Compression Valleys in LLMs are Two Sides of the S...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 204/563: 'Valid Stopping for LLM Generation via Empirical Dynamic Formal Lift...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 205/563: 'GUIDE: Guided Initialization and Distillation of Embeddings...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 206/563: 'ATLO-ML: Adaptive Time-Length Optimizer for Machine Learning -- Insigh...'
#   -> Shortlisted! (Interest) Score: 8.0/10
# Processing paper 207/563: 'Text-to-Image Models Leave Identifiable Signatures: Implications for L...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 208/563: 'Incoherence in goal-conditioned autoregressive models...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 209/563: 'The Markovian Thinker...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 210/563: 'The Framework That Survives Bad Models: Human-AI Collaboration For Cli...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 211/563: 'DPA-Net: A Dual-Path Attention Neural Network for Inferring Glycemic C...'
#   -> Skipped. Score below threshold: 6.0/10
# Processing paper 212/563: 'POME: Post Optimization Model Edit via Muon-style Projection...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 213/563: 'AI-Driven Forecasting and Monitoring of Urban Water System...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 214/563: 'Chem-NMF: Multi-layer $\alpha$-divergence Non-Negative Matrix Factoriz...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 215/563: 'Three Forms of Stochastic Injection for Improved Distribution-to-Distr...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 216/563: 'StruSR: Structure-Aware Symbolic Regression with Physics-Informed Tayl...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 217/563: 'Control-Augmented Autoregressive Diffusion for Data Assimilation...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 218/563: 'The False Promise of Zero-Shot Super-Resolution in Machine-Learned Ope...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 219/563: 'Local Reinforcement Learning with Action-Conditioned Root Mean Squared...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 220/563: 'Rethinking Nonlinearity: Trainable Gaussian Mixture Modules for Modern...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 221/563: 'XRPO: Pushing the limits of GRPO with Targeted Exploration and Exploit...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 222/563: 'TimeFormer: Transformer with Attention Modulation Empowered by Tempora...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 223/563: 'Distributed Algorithms for Multi-Agent Multi-Armed Bandits with Collis...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 224/563: 'AutoBalance: An Automatic Balancing Framework for Training Physics-Inf...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 225/563: 'Is the Hard-Label Cryptanalytic Model Extraction Really Polynomial?...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 226/563: 'A Diffusion Model for Regular Time Series Generation from Irregular Da...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 227/563: 'Dual Goal Representations...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 228/563: 'Incorporating Expert Knowledge into Bayesian Causal Discovery of Mixtu...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 229/563: 'Function regression using the forward forward training and inferring p...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 230/563: 'Modeling COVID-19 Dynamics in German States Using Physics-Informed Neu...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 231/563: 'Get RICH or Die Scaling: Profitably Trading Inference Compute for Robu...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 232/563: 'The Unreasonable Effectiveness of Randomized Representations in Online...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 233/563: 'Efficient numeracy in language models through single-token number embe...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 234/563: 'Recurrence-Complete Frame-based Action Models...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 235/563: 'Early wind turbine alarm prediction based on machine learning: AlarmFo...'
#   -> Shortlisted! (Interest) Score: 8.0/10
# Processing paper 236/563: 'Vectorized FlashAttention with Low-cost Exponential Computation in RIS...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 237/563: 'CNN-TFT explained by SHAP with multi-head attention weights for time s...'
#   -> Shortlisted! (Interest) Score: 8.0/10
# Processing paper 238/563: 'Enhancing Bankruptcy Prediction of Banks through Advanced Machine Lear...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 239/563: 'Towards Generalization of Graph Neural Networks for AC Optimal Power F...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 240/563: 'SaFeR-VLM: Toward Safety-aware Fine-grained Reasoning in Multimodal Mo...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 241/563: 'MoRE-GNN: Multi-omics Data Integration with a Heterogeneous Graph Auto...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 242/563: 'Angular Constraint Embedding via SpherePair Loss for Constrained Clust...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 243/563: 'Vacuum Spiker: A Spiking Neural Network-Based Model for Efficient Anom...'
#   -> Skipped. Score below threshold: 6.0/10
# Processing paper 244/563: 'Utilizing Large Language Models for Machine Learning Explainability...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 245/563: 'DecompGAIL: Learning Realistic Traffic Behaviors with Decomposed Multi...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 246/563: 'Revisiting Node Affinity Prediction in Temporal Graphs...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 247/563: 'Fisher Information, Training and Bias in Fourier Regression Models...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 248/563: 'Grouped Differential Attention...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 249/563: 'From Condensation to Rank Collapse: A Two-Stage Analysis of Transforme...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 250/563: 'High-Rate Mixout: Revisiting Mixout for Robust Domain Generalization...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 251/563: 'Revisiting Mixout: An Overlooked Path to Robust Finetuning...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 252/563: 'Spiral Model Technique For Data Science & Machine Learning Lifecycle...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 253/563: 'Sharpness-Aware Data Generation for Zero-shot Quantization...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 254/563: 'Federated Unlearning in the Wild: Rethinking Fairness and Data Discrep...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 255/563: 'Unified Molecule Pre-training with Flexible 2D and 3D Modalities: Sing...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 256/563: 'COMPASS: A Multi-Turn Benchmark for Tool-Mediated Planning & Preferenc...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 257/563: 'Enhancing Speech Emotion Recognition via Fine-Tuning Pre-Trained Model...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 258/563: 'Introspection in Learned Semantic Scene Graph Localisation...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 259/563: 'Blind Construction of Angular Power Maps in Massive MIMO Networks...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 260/563: 'HTMformer: Hybrid Time and Multivariate Transformer for Time Series Fo...'
#   -> Shortlisted! (Interest) Score: 8.0/10
# Processing paper 261/563: 'Non-Stationary Online Structured Prediction with Surrogate Losses...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 262/563: 'Generative World Modelling for Humanoids: 1X World Model Challenge Tec...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 263/563: 'A Multi-Agent Framework for Stateful Inference-Time Search...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 264/563: 'ELMUR: External Layer Memory with Update/Rewrite for Long-Horizon RL...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 265/563: 'Bridged Clustering for Representation Learning: Semi-Supervised Sparse...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 266/563: 'Poisoning Attacks on LLMs Require a Near-constant Number of Poison Sam...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 267/563: 'An in-depth look at approximation via deep and narrow neural networks...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 268/563: 'Guided by the Experts: Provable Feature Learning Dynamic of Soft-Route...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 269/563: 'A Broader View of Thompson Sampling...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 270/563: 'Discriminative Feature Feedback with General Teacher Classes...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 271/563: 'Test-Time Graph Search for Goal-Conditioned Reinforcement Learning...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 272/563: 'Dynamic Regret Bounds for Online Omniprediction with Long Term Constra...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 273/563: 'GTCN-G: A Residual Graph-Temporal Fusion Network for Imbalanced Intrus...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 274/563: 'Evolutionary Profiles for Protein Fitness Prediction...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 275/563: 'MolGA: Molecular Graph Adaptation with Pre-trained 2D Graph Encoder...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 276/563: 'MLE-Smith: Scaling MLE Tasks with Automated Multi-Agent Pipeline...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 277/563: 'h1: Bootstrapping LLMs to Reason over Longer Horizons via Reinforcemen...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 278/563: 'Enhancing Resilience for IoE: A Perspective of Networking-Level Safegu...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 279/563: 'Layerwise Federated Learning for Heterogeneous Quantum Clients using Q...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 280/563: 'Milestone Determination for Autonomous Railway Operation...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 281/563: 'Neu-RadBERT for Enhanced Diagnosis of Brain Injuries and Conditions...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 282/563: 'Uncertainty Quantification In Surface Landmines and UXO Classification...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 283/563: 'Evaluating Embedding Frameworks for Scientific Domain...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 284/563: 'Dream2Image : An Open Multimodal EEG Dataset for Decoding and Visualiz...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 285/563: 'Toward Uncertainty-Aware and Generalizable Neural Decoding for Quantum...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 286/563: 'Developing a Sequential Deep Learning Pipeline to Model Alaskan Permaf...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 287/563: 'Beyond Static Knowledge Messengers: Towards Adaptive, Fair, and Scalab...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 288/563: 'Ensemble Deep Learning and LLM-Assisted Reporting for Automated Skin L...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 289/563: 'AlphaApollo: Orchestrating Foundation Models and Professional Tools in...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 290/563: 'Prakriti200: A Questionnaire-Based Dataset of 200 Ayurvedic Prakriti A...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 291/563: 'Vision Transformer for Transient Noise Classification...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 292/563: 'Bridging Reasoning to Learning: Unmasking Illusions using Complexity O...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 293/563: 'General and Efficient Visual Goal-Conditioned Reinforcement Learning u...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 294/563: 'BuilderBench -- A benchmark for generalist agents...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 295/563: 'Soft-Evidence Fused Graph Neural Network for Cancer Driver Gene Identi...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 296/563: 'Efficient High-Resolution Image Editing with Hallucination-Aware Loss ...'
#   -> Skipped. Score below threshold: 1.0/10
# Processing paper 297/563: 'Scalable deep fusion of spaceborne lidar and synthetic aperture radar ...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 298/563: 'Conditional Denoising Diffusion Model-Based Robust MR Image Reconstruc...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 299/563: 'Asking For It: Question-Answering for Predicting Rule Infractions in O...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 300/563: 'TransFIRA: Transfer Learning for Face Image Recognizability Assessment...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 301/563: 'Diffusion-Guided Renormalization of Neural Systems via Tensor Networks...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 302/563: 'Road Surface Condition Detection with Machine Learning using New York ...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 303/563: 'BACHI: Boundary-Aware Symbolic Chord Recognition Through Masked Iterat...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 304/563: 'From Description to Detection: LLM based Extendable O-RAN Compliant Bl...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 305/563: 'Beneficial Reasoning Behaviors in Agentic Search and Effective Post-tr...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 306/563: 'Auto-Prompt Ensemble for LLM Judge...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 307/563: 'Cluster Paths: Navigating Interpretability in Neural Networks...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 308/563: 'From Acceleration to Saturation: Scaling Behavior of Bootstrapped Lang...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 309/563: 'Adapting Quantum Machine Learning for Energy Dissociation of Bonds...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 310/563: 'SDQM: Synthetic Data Quality Metric for Object Detection Dataset Evalu...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 311/563: 'FEAorta: A Fully Automated Framework for Finite Element Analysis of th...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 312/563: 'Unsupervised Backdoor Detection and Mitigation for Spiking Neural Netw...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 313/563: 'A Comparative Analysis of Contextual Representation Flow in State-Spac...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 314/563: 'Fitzpatrick Thresholding for Skin Image Segmentation...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 315/563: 'Incremental Summarization for Customer Support via Progressive Note-Ta...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 316/563: 'Latent Representation Learning in Heavy-Ion Collisions with MaskPoint ...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 317/563: 'Learning to Rewrite Prompts for Bootstrapping LLMs on Downstream Tasks...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 318/563: 'Inefficiencies of Meta Agents for Agent Design...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 319/563: 'Differentially Private Synthetic Text Generation for Retrieval-Augment...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 320/563: 'Scaling LLM Multi-turn RL with End-to-end Summarization-based Context ...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 321/563: 'MultiCNKG: Integrating Cognitive Neuroscience, Gene, and Disease Knowl...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 322/563: 'Quantum Computing Methods for Malware Detection...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 323/563: 'BlackboxNLP-2025 MIB Shared Task: Exploring Ensemble Strategies for Ci...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 324/563: 'Efficient Discriminative Joint Encoders for Large Scale Vision-Languag...'
#   -> Skipped. Score below threshold: 2.0/10
# ...
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 451/563: 'ACT-Tensor: Tensor Completion Framework for Financial Dataset Imputati...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 452/563: 'ProCut: LLM Prompt Compression via Attribution Estimation...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 453/563: 'An Investigation of Robustness of LLMs in Mathematical Reasoning: Benc...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 454/563: 'Interpretable Robot Control via Structured Behavior Trees and Large La...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 455/563: 'Enhancing GraphQL Security by Detecting Malicious Queries Using Large ...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 456/563: 'Machine Learning H-theorem...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 457/563: 'Membership Inference Attacks on LLM-based Recommender Systems...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 458/563: 'From Injection to Defense: Constructing Edit-Based Fingerprints for La...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 459/563: 'Sustainable LSTM-Based Precoding for RIS-Aided mmWave MIMO Systems wit...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 460/563: 'RespoDiff: Dual-Module Bottleneck Transformation for Responsible & Fai...'
#   -> Skipped. Score below threshold: 1.0/10
# Processing paper 461/563: 'Robot Learning from Any Images...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 462/563: 'VT-FSL: Bridging Vision and Text with LLMs for Few-Shot Learning...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 463/563: 'Baseline Systems For The 2025 Low-Resource Audio Codec Challenge...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 464/563: 'Platonic Transformers: A Solid Choice For Equivariance...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 465/563: 'Keep It on a Leash: Controllable Pseudo-label Generation Towards Reali...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 466/563: 'Epistemic Diversity and Knowledge Collapse in Large Language Models...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 467/563: 'Data-Driven Adaptive PID Control Based on Physics-Informed Neural Netw...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 468/563: 'ResMimic: From General Motion Tracking to Humanoid Whole-body Loco-Man...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 469/563: 'Scalable In-context Ranking with Generative Models...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 470/563: 'M\"obius transforms and Shapley values for vector-valued functions on ...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 471/563: 'DACP: Domain-Adaptive Continual Pre-Training of Large Language Models ...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 472/563: 'Nonparametric Estimation of Self- and Cross-Impact...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 473/563: 'Time-Varying Factor-Augmented Models for Volatility Forecasting...'
#   -> Shortlisted! (Relevant) Score: 9.0/10
# Processing paper 474/563: 'FEDS Paper: Illiquid Homeownership and the Bank of Mom and Dad...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 475/563: 'FEDS Paper: “Harvest Now Decrypt Later”: Examining Post-Quantum Crypto...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 476/563: 'FEDS Paper: Can LLMs Improve Sanctions Screening in the Financial Syst...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 477/563: 'FEDS Paper: Parallel Trends Forest: Data-Driven Control Sample Selecti...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 478/563: 'FEDS Paper: Financial Stability Implications of Generative AI: Taming ...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 479/563: 'IFDP Paper: Imperfect Information and Slow Recoveries in the Labor Mar...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 480/563: 'IFDP Paper: Clean Money, High Costs?...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 481/563: 'FEDS Paper: Virtue or Mirage? Complexity in Exchange Rate Prediction...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 482/563: 'FEDS Paper: Automated Credit Limit Increases and Consumer Welfare...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 483/563: 'IFDP Paper: Core Inflation in the Advanced Economies: A Regional Persp...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 484/563: 'FEDS Paper: One Policy Rate, Many Stances: Evidence from the European ...'
#   -> Skipped. Score below threshold: 7.0/10
# Processing paper 485/563: 'FEDS Paper: Where's The Bank? Banking Access in the Era of Branch Cons...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 486/563: 'FEDS Paper: Non-homothetic Demand Shifts and Inflation Inequality...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 487/563: 'FEDS Paper: Attention-Dependent Monetary Transmission to Household Bel...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 488/563: 'FEDS Paper: Monetary Policy and Bank Funding Costs: Patterns and Predi...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 489/563: 'Fiscal drag in theory and in practice: a European perspective...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 490/563: 'Capital requirements: a pillar or a burden for bank competitiveness?...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 491/563: 'Decoding climate-related risks in sovereign bond pricing: a global per...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 492/563: 'A comparative review of worldwide on-site banking supervision trends t...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 493/563: 'A study on the interaction of capital, liquidity and bank stability...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 494/563: 'The slope of the euro area price Phillips curve: evidence from regiona...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 495/563: 'How do rising temperatures affect inflation expectations?...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 496/563: 'From Brussels to Bangkok: how investment funds transmit financial spil...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 497/563: 'Macroprudential policy, monetary policy and non-bank financial interme...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 498/563: 'Hidden weaknesses: the role of unrealized losses in monetary policy tr...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 499/563: 'The impact of capital requirements on bank capital...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 500/563: 'Durability, essentiality, and the transmission of monetary policy to h...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 501/563: 'Foreign demand for safety and macroeconomic instability...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 502/563: 'Battle of the ages: distributional and aggregate effects of monetary p...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 503/563: 'The Great Moderation at 40: learning from the cross section...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 504/563: 'State Capacity, Institutions and Growth: Taxing for Takeoff—Revisiting...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 505/563: 'Fiscal Rules and Fiscal Councils: Recent Trends and Revisions since th...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 506/563: 'Recycling Risk: Synthetic Risk Transfers...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 507/563: 'External Shocks and Monetary Policy Trade-offs in Low-Income Countries...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 508/563: 'Restructuring Sovereign Domestic Debt in Developing Countries...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 509/563: 'The Effects of Fiscal Consolidations on the Debt Distribution...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 510/563: 'AI Projects in Financial Supervisory Authorities...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 511/563: 'Credit where Credit is Due: Fiscal Consolidations, Sovereign Risk and ...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 512/563: 'Monetary Policy and Housing Overvaluation...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 513/563: 'State Fragility: Towards a Conceptual Framework...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 514/563: 'DP20723 When Non-Uniform Carbon Prices are Efficient and Fair: Implica...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 515/563: 'DP20720 On the Limits of Hedging Inflation Risk in Investment Portfoli...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 516/563: 'DP20721 Income, Democracy, and Growth: Reconciling Evidence and Theory...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 517/563: 'DP20722 Payment Frictions, Capital Flows, and Exchange Rates...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 518/563: 'DP20719 Crypto Carry...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 519/563: 'DP20718 Dynamic Effects of Health Insurance Reform...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 520/563: 'DP20713 Social Learning among Urban Manufacturing Firms: Energy-Effici...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 521/563: 'DP20714 Building Consistent Territorial Units over Time: A Graph-Based...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 522/563: 'DP20711 Multiproduct Firms, Refunds and Product Returns...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 523/563: 'DP20716 A State Theory of Price Levels...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 524/563: 'DP20715 Identity and Institutional Change: Evidence from First Names i...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 525/563: 'DP20717 How Do Rising Temperatures Affect Inflation Expectations?...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 526/563: 'DP20712 More to Live for: Health Investment Responses to Expected Reti...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 527/563: 'DP20709 Mobile Broadband and the Decline of Incumbency Advantage...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 528/563: 'DP20710 What the Mercantilists Got Right...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 529/563: 'DP20705 Conflict and Investment:  A Review Across Health, Fertility, E...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 530/563: 'DP20704 Decomposing Comparative Development 1880-2020: A Quantitative ...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 531/563: 'DP20708 Demand Steering through the Smokescreen of Stockouts: Evidence...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 532/563: 'DP20707 Drivers of Switching in Autoinsurance: Evidence from Observabl...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 533/563: 'DP20706 Gender Gaps in Patience, Risk-Taking, Trust, and Prosociality ...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 534/563: 'DP20701 Skill Disruption and Post-Acquisition Employee Exit...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 535/563: 'DP20702 Disclosure, Patenting, and Trade Secrecy...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 536/563: 'DP20703 Auctions vs. Negotiations: The Role of the Payment Structure...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 537/563: 'DP20700 Two-Sided Market Pricing with Heterogeneous Users: Theory and ...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 538/563: 'DP20699 Public-Private Partnerships, Asymmetric Information, and Incom...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 539/563: 'DP20698 Ambiguity and the Variance of Gambles...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 540/563: 'DP20694 Sources of Consumer Information...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 541/563: 'DP20697 Work Intensity and Welfare Across Countries and Over Time...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 542/563: 'DP20696 Left Over or Opting Out? Squeeze, Mismatch and Surplus in Chin...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 543/563: 'DP20689 For Better or for Babies: Fertility Constraints and Marriage i...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 544/563: 'DP20693 Investing in Human Capital During Wartime: Experimental Eviden...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 545/563: 'DP20695 The Impact of Interest: Firms' Investment Sensitivity to Inter...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 546/563: 'DP20692 The Causal Effect of Parents' Education on Children's Earnings...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 547/563: 'DP20683 Bridging Quasi-Experimental and Structural Approaches for Robu...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 548/563: 'DP20690 Export Controls and Innovation in Sanctioned Countries...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 549/563: 'DP20691 Labor Markets, Financial Crises, and Inflation: Jobless and Wa...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 550/563: 'DP20687 The Inflationary Footprint of Fiscal Policy: Evidence from Dis...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 551/563: 'DP20686 Data, Power and Emissions: The Environmental Cost of AI...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 552/563: 'DP20685 The Labor Market Consequences of Acquisitions...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 553/563: 'DP20688 Demographic Trends and Government Debt Dynamics in the US and ...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 554/563: 'DP20684 Financial Value of Nature:  Coastal Housing Markets, Mangroves...'
#   -> Skipped. Score below threshold: 5.0/10
# Processing paper 555/563: 'DP20681 Ex Machina: Financial Stability in the Age of Artificial Intel...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 556/563: 'DP20682 Political Polarization and Human Capital Allocation...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 557/563: 'DP20678 Innovation Policies Under Economic Complexity...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 558/563: 'DP20679 Global Trends in Innovation Patterns: A Complexity Approach...'
#   -> Skipped. Score below threshold: 4.0/10
# Processing paper 559/563: 'DP20680 FCI-Plot: Central Bank Communication Through Financial Conditi...'
#   -> Shortlisted! (Relevant) Score: 8.0/10
# Processing paper 560/563: 'DP20677 Tariffs as Fiscal Policy...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 561/563: 'DP20676 Air Quality and Conferences' Engagement...'
#   -> Skipped. Score below threshold: 2.0/10
# Processing paper 562/563: 'DP20674 Specialization in Banking...'
#   -> Skipped. Score below threshold: 3.0/10
# Processing paper 563/563: 'DP20675 Systemic Cyber Risk: Linking Measurement, Market Incentives, a...'
#   -> Skipped. Score below threshold: 2.0/10
# ✅ Internal review file saved: newsletters/ets4_monthly_2025-10-09_INTERNAL.md
# ✅ Public newsletter file saved: newsletters/ets4_monthly_2025-10-09_PUBLIC.md
#
# --- Pipeline Finished ---
# Total unique papers processed by LLM: 563
# Shortlisted 24 'Directly Relevant' papers.
# Shortlisted 9 'Papers of Interest'.
